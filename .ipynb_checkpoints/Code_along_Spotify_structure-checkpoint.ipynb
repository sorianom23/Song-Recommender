# %% [markdown]
# # Installing Spotipy

# %% [markdown]
# In order to use the Spotify API (SpotiPy) we will have to create an account in Spotify and follow these steps. Once we have done it we will start initializing the API and look at the search method for which we can introduce a "query" q, in this example we will try it with Lady Gaga:

# %%
# !pip install spotipy
# Out:
# Collecting spotipy
#   Downloading spotipy-2.19.0-py3-none-any.whl (27 kB)
# Collecting urllib3>=1.26.0
#   Downloading urllib3-1.26.9-py2.py3-none-any.whl (138 kB)
#      |████████████████████████████████| 138 kB 10.3 MB/s
# Collecting requests>=2.25.0
#   Downloading requests-2.27.1-py2.py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 1.6 MB/s
# Requirement already satisfied: six>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spotipy) (1.15.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.25.0->spotipy) (2.10)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.7/dist-packages (from requests>=2.25.0->spotipy) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.25.0->spotipy) (2021.10.8)
# Installing collected packages: urllib3, requests, spotipy
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests~=2.23.0, but you have requests 2.27.1 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# Successfully installed requests-2.27.1 spotipy-2.19.0 urllib3-1.26.9

# %% [markdown]
# ## Loading credentials from another config file

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
sys.path.insert(1, '/content/drive/MyDrive/Credentials/')
from config import *

# %% [markdown]
# ## Starting with Spotify API

# %%
import spotipy
import json
from spotipy.oauth2 import SpotifyClientCredentials


#Initialize SpotiPy with user credentias
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id= Client_ID,
                                                           client_secret= Client_Secret))

# The "sp" variable has two useful funtions:
# The first usefull function is:
# .search(q='',limit=n)
# .search(q="track:"+song_name+" artist:"+artist_name,limit=5) to restrict to a song name and artist.
# Where the "q" keyword is the query you want to perform on spotify: song_name, artist,...
# while The "limit" keyword will limit the number of returned results.
#
# The second usefull function is:
# .audio_features([URL|URI|ID])
# which returns some 'features of the song', that after cleanup, we can use in order to characterize a song.

results = sp.search(q='Yann Tiersen', limit=5)
results
#json_results = json.dumps(results, ensure_ascii=True)
#json_results
#results['tracks']['items'][0]['album']
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Yann+Tiersen&type=track&offset=0&limit=5',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00sazWvoTLOqg5MFwC68Um'},
#        'href': 'https://api.spotify.com/v1/artists/00sazWvoTLOqg5MFwC68Um',
#        'id': '00sazWvoTLOqg5MFwC68Um',
#        'name': 'Yann Tiersen',
#        'type': 'artist',
#        'uri': 'spotify:artist:00sazWvoTLOqg5MFwC68Um'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6PRPYATK5VvjZ2p911y6U0'},
#      'href': 'https://api.spotify.com/v1/albums/6PRPYATK5VvjZ2p911y6U0',
#      'id': '6PRPYATK5VvjZ2p911y6U0',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2731b7844a8c73c4d48f0bca1de',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e021b7844a8c73c4d48f0bca1de',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048511b7844a8c73c4d48f0bca1de',
#        'width': 64}],
#      'name': "Le Fabuleux destin d'Amélie Poulain (Bande originale du film)",
#      'release_date': '2001-04-23',
#      'release_date_precision': 'day',
#      'total_tracks': 15,
#      'type': 'album',
#      'uri': 'spotify:album:6PRPYATK5VvjZ2p911y6U0'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00sazWvoTLOqg5MFwC68Um'},
#       'href': 'https://api.spotify.com/v1/artists/00sazWvoTLOqg5MFwC68Um',
#       'id': '00sazWvoTLOqg5MFwC68Um',
#       'name': 'Yann Tiersen',
#       'type': 'artist',
#       'uri': 'spotify:artist:00sazWvoTLOqg5MFwC68Um'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 140733,
#     'explicit': False,
#     'external_ids': {'isrc': 'FR91U0100002'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/14rZjW3RioG7WesZhYESso'},
#     'href': 'https://api.spotify.com/v1/tracks/14rZjW3RioG7WesZhYESso',
#     'id': '14rZjW3RioG7WesZhYESso',
#     'is_local': False,
#     'name': "Comptine d'un autre été, l'après-midi",
#     'popularity': 77,
#     'preview_url': 'https://p.scdn.co/mp3-preview/c3395706db3ffb40a9fefd855141fbad15f78881?cid=0912c34e16c349f28a330c0eba3cc52f',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:14rZjW3RioG7WesZhYESso'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00sazWvoTLOqg5MFwC68Um'},
#        'href': 'https://api.spotify.com/v1/artists/00sazWvoTLOqg5MFwC68Um',
#        'id': '00sazWvoTLOqg5MFwC68Um',
#        'name': 'Yann Tiersen',
#        'type': 'artist',
#        'uri': 'spotify:artist:00sazWvoTLOqg5MFwC68Um'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6PRPYATK5VvjZ2p911y6U0'},
#      'href': 'https://api.spotify.com/v1/albums/6PRPYATK5VvjZ2p911y6U0',
#      'id': '6PRPYATK5VvjZ2p911y6U0',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2731b7844a8c73c4d48f0bca1de',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e021b7844a8c73c4d48f0bca1de',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048511b7844a8c73c4d48f0bca1de',
#        'width': 64}],
#      'name': "Le Fabuleux destin d'Amélie Poulain (Bande originale du film)",
#      'release_date': '2001-04-23',
#      'release_date_precision': 'day',
#      'total_tracks': 15,
#      'type': 'album',
#      'uri': 'spotify:album:6PRPYATK5VvjZ2p911y6U0'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00sazWvoTLOqg5MFwC68Um'},
#       'href': 'https://api.spotify.com/v1/artists/00sazWvoTLOqg5MFwC68Um',
#       'id': '00sazWvoTLOqg5MFwC68Um',
#       'name': 'Yann Tiersen',
#       'type': 'artist',
#       'uri': 'spotify:artist:00sazWvoTLOqg5MFwC68Um'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 158666,
#     'explicit': False,
#     'external_ids': {'isrc': 'FR91U0100008'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6bpmBNPfQ2KFAW0ik6F9Vq'},
#     'href': 'https://api.spotify.com/v1/tracks/6bpmBNPfQ2KFAW0ik6F9Vq',
#     'id': '6bpmBNPfQ2KFAW0ik6F9Vq',
#     'is_local': False,
#     'name': "La Valse d'Amélie - Version piano",
#     'popularity': 67,
#     'preview_url': 'https://p.scdn.co/mp3-preview/273992bc4da8b34a3bd931de90f72a918c8f7fdd?cid=0912c34e16c349f28a330c0eba3cc52f',
#     'track_number': 10,
#     'type': 'track',
#     'uri': 'spotify:track:6bpmBNPfQ2KFAW0ik6F9Vq'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GH',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JP',
#       'KE',
#       'KH',
#       'KR',
#       'KW',
#       'LB',
#       'LK',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SN',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TT',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VE',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3UlHVFGJXAQzfLFPgEATkv'},
#      'href': 'https://api.spotify.com/v1/albums/3UlHVFGJXAQzfLFPgEATkv',
#      'id': '3UlHVFGJXAQzfLFPgEATkv',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27344f04044b11351867db15022',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0244f04044b11351867db15022',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485144f04044b11351867db15022',
#        'width': 64}],
#      'name': 'Dolce dormire classic relaxing piano',
#      'release_date': '2022-03-16',
#      'release_date_precision': 'day',
#      'total_tracks': 52,
#      'type': 'album',
#      'uri': 'spotify:album:3UlHVFGJXAQzfLFPgEATkv'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00sazWvoTLOqg5MFwC68Um'},
#       'href': 'https://api.spotify.com/v1/artists/00sazWvoTLOqg5MFwC68Um',
#       'id': '00sazWvoTLOqg5MFwC68Um',
#       'name': 'Yann Tiersen',
#       'type': 'artist',
#       'uri': 'spotify:artist:00sazWvoTLOqg5MFwC68Um'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1ylcY77FWeSVQKh5et1VGp'},
#       'href': 'https://api.spotify.com/v1/artists/1ylcY77FWeSVQKh5et1VGp',
#       'id': '1ylcY77FWeSVQKh5et1VGp',
#       'name': 'Music Lab Collective',
#       'type': 'artist',
#       'uri': 'spotify:artist:1ylcY77FWeSVQKh5et1VGp'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/0gOrXuu1vCBXe3pwTyb5Ca'},
#       'href': 'https://api.spotify.com/v1/artists/0gOrXuu1vCBXe3pwTyb5Ca',
#       'id': '0gOrXuu1vCBXe3pwTyb5Ca',
#       'name': 'Valentina Lisitsa',
#       'type': 'artist',
#       'uri': 'spotify:artist:0gOrXuu1vCBXe3pwTyb5Ca'}],
#     'available_markets': ['AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GH',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JP',
#      'KE',
#      'KH',
#      'KR',
#      'KW',
#      'LB',
#      'LK',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SN',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TT',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VE',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 156560,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBF071401810'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4pZ3z8fTyFlg7txomZi3OY'},
#     'href': 'https://api.spotify.com/v1/tracks/4pZ3z8fTyFlg7txomZi3OY',
#     'id': '4pZ3z8fTyFlg7txomZi3OY',
#     'is_local': False,
#     'name': 'Comptine d’un autre été: L’après-midi',
#     'popularity': 4,
#     'preview_url': None,
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:4pZ3z8fTyFlg7txomZi3OY'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GH',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JP',
#       'KE',
#       'KH',
#       'KR',
#       'KW',
#       'LB',
#       'LK',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SN',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TT',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VE',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/777R3zysBRXTylrmWJ0Jhx'},
#      'href': 'https://api.spotify.com/v1/albums/777R3zysBRXTylrmWJ0Jhx',
#      'id': '777R3zysBRXTylrmWJ0Jhx',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27337a55584df5b8c31b0a252d6',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0237a55584df5b8c31b0a252d6',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485137a55584df5b8c31b0a252d6',
#        'width': 64}],
#      'name': 'Sleepy Piano Music',
#      'release_date': '2022-03-18',
#      'release_date_precision': 'day',
#      'total_tracks': 397,
#      'type': 'album',
#      'uri': 'spotify:album:777R3zysBRXTylrmWJ0Jhx'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00sazWvoTLOqg5MFwC68Um'},
#       'href': 'https://api.spotify.com/v1/artists/00sazWvoTLOqg5MFwC68Um',
#       'id': '00sazWvoTLOqg5MFwC68Um',
#       'name': 'Yann Tiersen',
#       'type': 'artist',
#       'uri': 'spotify:artist:00sazWvoTLOqg5MFwC68Um'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1ylcY77FWeSVQKh5et1VGp'},
#       'href': 'https://api.spotify.com/v1/artists/1ylcY77FWeSVQKh5et1VGp',
#       'id': '1ylcY77FWeSVQKh5et1VGp',
#       'name': 'Music Lab Collective',
#       'type': 'artist',
#       'uri': 'spotify:artist:1ylcY77FWeSVQKh5et1VGp'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/0gOrXuu1vCBXe3pwTyb5Ca'},
#       'href': 'https://api.spotify.com/v1/artists/0gOrXuu1vCBXe3pwTyb5Ca',
#       'id': '0gOrXuu1vCBXe3pwTyb5Ca',
#       'name': 'Valentina Lisitsa',
#       'type': 'artist',
#       'uri': 'spotify:artist:0gOrXuu1vCBXe3pwTyb5Ca'}],
#     'available_markets': ['AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GH',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JP',
#      'KE',
#      'KH',
#      'KR',
#      'KW',
#      'LB',
#      'LK',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SN',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TT',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VE',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 156560,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBF071401810'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/24ylgZD6saa4DoFdig8zDW'},
#     'href': 'https://api.spotify.com/v1/tracks/24ylgZD6saa4DoFdig8zDW',
#     'id': '24ylgZD6saa4DoFdig8zDW',
#     'is_local': False,
#     'name': 'Comptine d’un autre été: L’après-midi',
#     'popularity': 0,
#     'preview_url': None,
#     'track_number': 187,
#     'type': 'track',
#     'uri': 'spotify:track:24ylgZD6saa4DoFdig8zDW'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GH',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JP',
#       'KE',
#       'KH',
#       'KR',
#       'KW',
#       'LB',
#       'LK',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SN',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TT',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VE',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/40X1rALZZjnSwyY6hGQxzk'},
#      'href': 'https://api.spotify.com/v1/albums/40X1rALZZjnSwyY6hGQxzk',
#      'id': '40X1rALZZjnSwyY6hGQxzk',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273e042ffbe0c5e8da2e630cb02',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02e042ffbe0c5e8da2e630cb02',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851e042ffbe0c5e8da2e630cb02',
#        'width': 64}],
#      'name': 'Enjoy Easter Time',
#      'release_date': '2022-03-11',
#      'release_date_precision': 'day',
#      'total_tracks': 57,
#      'type': 'album',
#      'uri': 'spotify:album:40X1rALZZjnSwyY6hGQxzk'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00sazWvoTLOqg5MFwC68Um'},
#       'href': 'https://api.spotify.com/v1/artists/00sazWvoTLOqg5MFwC68Um',
#       'id': '00sazWvoTLOqg5MFwC68Um',
#       'name': 'Yann Tiersen',
#       'type': 'artist',
#       'uri': 'spotify:artist:00sazWvoTLOqg5MFwC68Um'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1ylcY77FWeSVQKh5et1VGp'},
#       'href': 'https://api.spotify.com/v1/artists/1ylcY77FWeSVQKh5et1VGp',
#       'id': '1ylcY77FWeSVQKh5et1VGp',
#       'name': 'Music Lab Collective',
#       'type': 'artist',
#       'uri': 'spotify:artist:1ylcY77FWeSVQKh5et1VGp'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/0gOrXuu1vCBXe3pwTyb5Ca'},
#       'href': 'https://api.spotify.com/v1/artists/0gOrXuu1vCBXe3pwTyb5Ca',
#       'id': '0gOrXuu1vCBXe3pwTyb5Ca',
#       'name': 'Valentina Lisitsa',
#       'type': 'artist',
#       'uri': 'spotify:artist:0gOrXuu1vCBXe3pwTyb5Ca'}],
#     'available_markets': ['AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GH',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JP',
#      'KE',
#      'KH',
#      'KR',
#      'KW',
#      'LB',
#      'LK',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SN',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TT',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VE',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 156560,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBF071401810'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4gXYgWlBHPCJvEIrQ9wwrS'},
#     'href': 'https://api.spotify.com/v1/tracks/4gXYgWlBHPCJvEIrQ9wwrS',
#     'id': '4gXYgWlBHPCJvEIrQ9wwrS',
#     'is_local': False,
#     'name': 'Comptine d’un autre été: L’après-midi',
#     'popularity': 1,
#     'preview_url': None,
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:4gXYgWlBHPCJvEIrQ9wwrS'}],
#   'limit': 5,
#   'next': 'https://api.spotify.com/v1/search?query=Yann+Tiersen&type=track&offset=5&limit=5',
#   'offset': 0,
#   'previous': None,
#   'total': 1222}}

# %% [markdown]
# {'spotify': 'https://open.spotify.com/track/4O2N861eOnF9q8EtpH8IJu'}

# %%
type(results)
# Out:
# dict

# %%
results.keys()
# Out:
# dict_keys(['tracks'])

# %%
results['tracks'].keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
import pprint

pprint.pprint(results)
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Yann+Tiersen&type=track&offset=0&limit=5',
#             'items': [{'album': {'album_type': 'album',
#                                  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00sazWvoTLOqg5MFwC68Um'},
#                                               'href': 'https://api.spotify.com/v1/artists/00sazWvoTLOqg5MFwC68Um',
#                                               'id': '00sazWvoTLOqg5MFwC68Um',
#                                               'name': 'Yann Tiersen',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:00sazWvoTLOqg5MFwC68Um'}],
#                                  'available_markets': ['AD',
#                                                        'AE',
#                                                        'AG',
#                                                        'AL',
#                                                        'AM',
#                                                        'AO',
#                                                        'AR',
#                                                        'AT',
#                                                        'AU',
#                                                        'AZ',
#                                                        'BA',
#                                                        'BB',
#                                                        'BD',
#                                                        'BE',
#                                                        'BF',
#                                                        'BG',
#                                                        'BH',
#                                                        'BI',
#                                                        'BJ',
#                                                        'BN',
#                                                        'BO',
#                                                        'BR',
#                                                        'BS',
#                                                        'BT',
#                                                        'BW',
#                                                        'BY',
#                                                        'BZ',
#                                                        'CA',
#                                                        'CD',
#                                                        'CG',
#                                                        'CH',
#                                                        'CI',
#                                                        'CL',
#                                                        'CM',
#                                                        'CO',
#                                                        'CR',
#                                                        'CV',
#                                                        'CW',
#                                                        'CY',
#                                                        'CZ',
#                                                        'DE',
#                                                        'DJ',
#                                                        'DK',
#                                                        'DM',
#                                                        'DO',
#                                                        'DZ',
#                                                        'EC',
#                                                        'EE',
#                                                        'EG',
#                                                        'ES',
#                                                        'FI',
#                                                        'FJ',
#                                                        'FM',
#                                                        'FR',
#                                                        'GA',
#                                                        'GB',
#                                                        'GD',
#                                                        'GE',
#                                                        'GH',
#                                                        'GM',
#                                                        'GN',
#                                                        'GQ',
#                                                        'GR',
#                                                        'GT',
#                                                        'GW',
#                                                        'GY',
#                                                        'HK',
#                                                        'HN',
#                                                        'HR',
#                                                        'HT',
#                                                        'HU',
#                                                        'ID',
#                                                        'IE',
#                                                        'IL',
#                                                        'IN',
#                                                        'IQ',
#                                                        'IS',
#                                                        'IT',
#                                                        'JM',
#                                                        'JO',
#                                                        'JP',
#                                                        'KE',
#                                                        'KG',
#                                                        'KH',
#                                                        'KI',
#                                                        'KM',
#                                                        'KN',
#                                                        'KR',
#                                                        'KW',
#                                                        'KZ',
#                                                        'LA',
#                                                        'LB',
#                                                        'LC',
#                                                        'LI',
#                                                        'LK',
#                                                        'LR',
#                                                        'LS',
#                                                        'LT',
#                                                        'LU',
#                                                        'LV',
#                                                        'LY',
#                                                        'MA',
#                                                        'MC',
#                                                        'MD',
#                                                        'ME',
#                                                        'MG',
#                                                        'MH',
#                                                        'MK',
#                                                        'ML',
#                                                        'MN',
#                                                        'MO',
#                                                        'MR',
#                                                        'MT',
#                                                        'MU',
#                                                        'MV',
#                                                        'MW',
#                                                        'MX',
#                                                        'MY',
#                                                        'MZ',
#                                                        'NA',
#                                                        'NE',
#                                                        'NG',
#                                                        'NI',
#                                                        'NL',
#                                                        'NO',
#                                                        'NP',
#                                                        'NR',
#                                                        'NZ',
#                                                        'OM',
#                                                        'PA',
#                                                        'PE',
#                                                        'PG',
#                                                        'PH',
#                                                        'PK',
#                                                        'PL',
#                                                        'PS',
#                                                        'PT',
#                                                        'PW',
#                                                        'PY',
#                                                        'QA',
#                                                        'RO',
#                                                        'RS',
#                                                        'RU',
#                                                        'RW',
#                                                        'SA',
#                                                        'SB',
#                                                        'SC',
#                                                        'SE',
#                                                        'SG',
#                                                        'SI',
#                                                        'SK',
#                                                        'SL',
#                                                        'SM',
#                                                        'SN',
#                                                        'SR',
#                                                        'ST',
#                                                        'SV',
#                                                        'SZ',
#                                                        'TD',
#                                                        'TG',
#                                                        'TH',
#                                                        'TJ',
#                                                        'TL',
#                                                        'TN',
#                                                        'TO',
#                                                        'TR',
#                                                        'TT',
#                                                        'TV',
#                                                        'TW',
#                                                        'TZ',
#                                                        'UA',
#                                                        'UG',
#                                                        'US',
#                                                        'UY',
#                                                        'UZ',
#                                                        'VC',
#                                                        'VE',
#                                                        'VN',
#                                                        'VU',
#                                                        'WS',
#                                                        'XK',
#                                                        'ZA',
#                                                        'ZM',
#                                                        'ZW'],
#                                  'external_urls': {'spotify': 'https://open.spotify.com/album/6PRPYATK5VvjZ2p911y6U0'},
#                                  'href': 'https://api.spotify.com/v1/albums/6PRPYATK5VvjZ2p911y6U0',
#                                  'id': '6PRPYATK5VvjZ2p911y6U0',
#                                  'images': [{'height': 640,
#                                              'url': 'https://i.scdn.co/image/ab67616d0000b2731b7844a8c73c4d48f0bca1de',
#                                              'width': 640},
#                                             {'height': 300,
#                                              'url': 'https://i.scdn.co/image/ab67616d00001e021b7844a8c73c4d48f0bca1de',
#                                              'width': 300},
#                                             {'height': 64,
#                                              'url': 'https://i.scdn.co/image/ab67616d000048511b7844a8c73c4d48f0bca1de',
#                                              'width': 64}],
#                                  'name': "Le Fabuleux destin d'Amélie Poulain "
#                                          '(Bande originale du film)',
#                                  'release_date': '2001-04-23',
#                                  'release_date_precision': 'day',
#                                  'total_tracks': 15,
#                                  'type': 'album',
#                                  'uri': 'spotify:album:6PRPYATK5VvjZ2p911y6U0'},
#                        'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00sazWvoTLOqg5MFwC68Um'},
#                                     'href': 'https://api.spotify.com/v1/artists/00sazWvoTLOqg5MFwC68Um',
#                                     'id': '00sazWvoTLOqg5MFwC68Um',
#                                     'name': 'Yann Tiersen',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:00sazWvoTLOqg5MFwC68Um'}],
#                        'available_markets': ['AD',
#                                              'AE',
#                                              'AG',
#                                              'AL',
#                                              'AM',
#                                              'AO',
#                                              'AR',
#                                              'AT',
#                                              'AU',
#                                              'AZ',
#                                              'BA',
#                                              'BB',
#                                              'BD',
#                                              'BE',
#                                              'BF',
#                                              'BG',
#                                              'BH',
#                                              'BI',
#                                              'BJ',
#                                              'BN',
#                                              'BO',
#                                              'BR',
#                                              'BS',
#                                              'BT',
#                                              'BW',
#                                              'BY',
#                                              'BZ',
#                                              'CA',
#                                              'CD',
#                                              'CG',
#                                              'CH',
#                                              'CI',
#                                              'CL',
#                                              'CM',
#                                              'CO',
#                                              'CR',
#                                              'CV',
#                                              'CW',
#                                              'CY',
#                                              'CZ',
#                                              'DE',
#                                              'DJ',
#                                              'DK',
#                                              'DM',
#                                              'DO',
#                                              'DZ',
#                                              'EC',
#                                              'EE',
#                                              'EG',
#                                              'ES',
#                                              'FI',
#                                              'FJ',
#                                              'FM',
#                                              'FR',
#                                              'GA',
#                                              'GB',
#                                              'GD',
#                                              'GE',
#                                              'GH',
#                                              'GM',
#                                              'GN',
#                                              'GQ',
#                                              'GR',
#                                              'GT',
#                                              'GW',
#                                              'GY',
#                                              'HK',
#                                              'HN',
#                                              'HR',
#                                              'HT',
#                                              'HU',
#                                              'ID',
#                                              'IE',
#                                              'IL',
#                                              'IN',
#                                              'IQ',
#                                              'IS',
#                                              'IT',
#                                              'JM',
#                                              'JO',
#                                              'JP',
#                                              'KE',
#                                              'KG',
#                                              'KH',
#                                              'KI',
#                                              'KM',
#                                              'KN',
#                                              'KR',
#                                              'KW',
#                                              'KZ',
#                                              'LA',
#                                              'LB',
#                                              'LC',
#                                              'LI',
#                                              'LK',
#                                              'LR',
#                                              'LS',
#                                              'LT',
#                                              'LU',
#                                              'LV',
#                                              'LY',
#                                              'MA',
#                                              'MC',
#                                              'MD',
#                                              'ME',
#                                              'MG',
#                                              'MH',
#                                              'MK',
#                                              'ML',
#                                              'MN',
#                                              'MO',
#                                              'MR',
#                                              'MT',
#                                              'MU',
#                                              'MV',
#                                              'MW',
#                                              'MX',
#                                              'MY',
#                                              'MZ',
#                                              'NA',
#                                              'NE',
#                                              'NG',
#                                              'NI',
#                                              'NL',
#                                              'NO',
#                                              'NP',
#                                              'NR',
#                                              'NZ',
#                                              'OM',
#                                              'PA',
#                                              'PE',
#                                              'PG',
#                                              'PH',
#                                              'PK',
#                                              'PL',
#                                              'PS',
#                                              'PT',
#                                              'PW',
#                                              'PY',
#                                              'QA',
#                                              'RO',
#                                              'RS',
#                                              'RU',
#                                              'RW',
#                                              'SA',
#                                              'SB',
#                                              'SC',
#                                              'SE',
#                                              'SG',
#                                              'SI',
#                                              'SK',
#                                              'SL',
#                                              'SM',
#                                              'SN',
#                                              'SR',
#                                              'ST',
#                                              'SV',
#                                              'SZ',
#                                              'TD',
#                                              'TG',
#                                              'TH',
#                                              'TJ',
#                                              'TL',
#                                              'TN',
#                                              'TO',
#                                              'TR',
#                                              'TT',
#                                              'TV',
#                                              'TW',
#                                              'TZ',
#                                              'UA',
#                                              'UG',
#                                              'US',
#                                              'UY',
#                                              'UZ',
#                                              'VC',
#                                              'VE',
#                                              'VN',
#                                              'VU',
#                                              'WS',
#                                              'XK',
#                                              'ZA',
#                                              'ZM',
#                                              'ZW'],
#                        'disc_number': 1,
#                        'duration_ms': 140733,
#                        'explicit': False,
#                        'external_ids': {'isrc': 'FR91U0100002'},
#                        'external_urls': {'spotify': 'https://open.spotify.com/track/14rZjW3RioG7WesZhYESso'},
#                        'href': 'https://api.spotify.com/v1/tracks/14rZjW3RioG7WesZhYESso',
#                        'id': '14rZjW3RioG7WesZhYESso',
#                        'is_local': False,
#                        'name': "Comptine d'un autre été, l'après-midi",
#                        'popularity': 77,
#                        'preview_url': 'https://p.scdn.co/mp3-preview/c3395706db3ffb40a9fefd855141fbad15f78881?cid=0912c34e16c349f28a330c0eba3cc52f',
#                        'track_number': 3,
#                        'type': 'track',
#                        'uri': 'spotify:track:14rZjW3RioG7WesZhYESso'},
#                       {'album': {'album_type': 'album',
#                                  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00sazWvoTLOqg5MFwC68Um'},
#                                               'href': 'https://api.spotify.com/v1/artists/00sazWvoTLOqg5MFwC68Um',
#                                               'id': '00sazWvoTLOqg5MFwC68Um',
#                                               'name': 'Yann Tiersen',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:00sazWvoTLOqg5MFwC68Um'}],
#                                  'available_markets': ['AD',
#                                                        'AE',
#                                                        'AG',
#                                                        'AL',
#                                                        'AM',
#                                                        'AO',
#                                                        'AR',
#                                                        'AT',
#                                                        'AU',
#                                                        'AZ',
#                                                        'BA',
#                                                        'BB',
#                                                        'BD',
#                                                        'BE',
#                                                        'BF',
#                                                        'BG',
#                                                        'BH',
#                                                        'BI',
#                                                        'BJ',
#                                                        'BN',
#                                                        'BO',
#                                                        'BR',
#                                                        'BS',
#                                                        'BT',
#                                                        'BW',
#                                                        'BY',
#                                                        'BZ',
#                                                        'CA',
#                                                        'CD',
#                                                        'CG',
#                                                        'CH',
#                                                        'CI',
#                                                        'CL',
#                                                        'CM',
#                                                        'CO',
#                                                        'CR',
#                                                        'CV',
#                                                        'CW',
#                                                        'CY',
#                                                        'CZ',
#                                                        'DE',
#                                                        'DJ',
#                                                        'DK',
#                                                        'DM',
#                                                        'DO',
#                                                        'DZ',
#                                                        'EC',
#                                                        'EE',
#                                                        'EG',
#                                                        'ES',
#                                                        'FI',
#                                                        'FJ',
#                                                        'FM',
#                                                        'FR',
#                                                        'GA',
#                                                        'GB',
#                                                        'GD',
#                                                        'GE',
#                                                        'GH',
#                                                        'GM',
#                                                        'GN',
#                                                        'GQ',
#                                                        'GR',
#                                                        'GT',
#                                                        'GW',
#                                                        'GY',
#                                                        'HK',
#                                                        'HN',
#                                                        'HR',
#                                                        'HT',
#                                                        'HU',
#                                                        'ID',
#                                                        'IE',
#                                                        'IL',
#                                                        'IN',
#                                                        'IQ',
#                                                        'IS',
#                                                        'IT',
#                                                        'JM',
#                                                        'JO',
#                                                        'JP',
#                                                        'KE',
#                                                        'KG',
#                                                        'KH',
#                                                        'KI',
#                                                        'KM',
#                                                        'KN',
#                                                        'KR',
#                                                        'KW',
#                                                        'KZ',
#                                                        'LA',
#                                                        'LB',
#                                                        'LC',
#                                                        'LI',
#                                                        'LK',
#                                                        'LR',
#                                                        'LS',
#                                                        'LT',
#                                                        'LU',
#                                                        'LV',
#                                                        'LY',
#                                                        'MA',
#                                                        'MC',
#                                                        'MD',
#                                                        'ME',
#                                                        'MG',
#                                                        'MH',
#                                                        'MK',
#                                                        'ML',
#                                                        'MN',
#                                                        'MO',
#                                                        'MR',
#                                                        'MT',
#                                                        'MU',
#                                                        'MV',
#                                                        'MW',
#                                                        'MX',
#                                                        'MY',
#                                                        'MZ',
#                                                        'NA',
#                                                        'NE',
#                                                        'NG',
#                                                        'NI',
#                                                        'NL',
#                                                        'NO',
#                                                        'NP',
#                                                        'NR',
#                                                        'NZ',
#                                                        'OM',
#                                                        'PA',
#                                                        'PE',
#                                                        'PG',
#                                                        'PH',
#                                                        'PK',
#                                                        'PL',
#                                                        'PS',
#                                                        'PT',
#                                                        'PW',
#                                                        'PY',
#                                                        'QA',
#                                                        'RO',
#                                                        'RS',
#                                                        'RU',
#                                                        'RW',
#                                                        'SA',
#                                                        'SB',
#                                                        'SC',
#                                                        'SE',
#                                                        'SG',
#                                                        'SI',
#                                                        'SK',
#                                                        'SL',
#                                                        'SM',
#                                                        'SN',
#                                                        'SR',
#                                                        'ST',
#                                                        'SV',
#                                                        'SZ',
#                                                        'TD',
#                                                        'TG',
#                                                        'TH',
#                                                        'TJ',
#                                                        'TL',
#                                                        'TN',
#                                                        'TO',
#                                                        'TR',
#                                                        'TT',
#                                                        'TV',
#                                                        'TW',
#                                                        'TZ',
#                                                        'UA',
#                                                        'UG',
#                                                        'US',
#                                                        'UY',
#                                                        'UZ',
#                                                        'VC',
#                                                        'VE',
#                                                        'VN',
#                                                        'VU',
#                                                        'WS',
#                                                        'XK',
#                                                        'ZA',
#                                                        'ZM',
#                                                        'ZW'],
#                                  'external_urls': {'spotify': 'https://open.spotify.com/album/6PRPYATK5VvjZ2p911y6U0'},
#                                  'href': 'https://api.spotify.com/v1/albums/6PRPYATK5VvjZ2p911y6U0',
#                                  'id': '6PRPYATK5VvjZ2p911y6U0',
#                                  'images': [{'height': 640,
#                                              'url': 'https://i.scdn.co/image/ab67616d0000b2731b7844a8c73c4d48f0bca1de',
#                                              'width': 640},
#                                             {'height': 300,
#                                              'url': 'https://i.scdn.co/image/ab67616d00001e021b7844a8c73c4d48f0bca1de',
#                                              'width': 300},
#                                             {'height': 64,
#                                              'url': 'https://i.scdn.co/image/ab67616d000048511b7844a8c73c4d48f0bca1de',
#                                              'width': 64}],
#                                  'name': "Le Fabuleux destin d'Amélie Poulain "
#                                          '(Bande originale du film)',
#                                  'release_date': '2001-04-23',
#                                  'release_date_precision': 'day',
#                                  'total_tracks': 15,
#                                  'type': 'album',
#                                  'uri': 'spotify:album:6PRPYATK5VvjZ2p911y6U0'},
#                        'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00sazWvoTLOqg5MFwC68Um'},
#                                     'href': 'https://api.spotify.com/v1/artists/00sazWvoTLOqg5MFwC68Um',
#                                     'id': '00sazWvoTLOqg5MFwC68Um',
#                                     'name': 'Yann Tiersen',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:00sazWvoTLOqg5MFwC68Um'}],
#                        'available_markets': ['AD',
#                                              'AE',
#                                              'AG',
#                                              'AL',
#                                              'AM',
#                                              'AO',
#                                              'AR',
#                                              'AT',
#                                              'AU',
#                                              'AZ',
#                                              'BA',
#                                              'BB',
#                                              'BD',
#                                              'BE',
#                                              'BF',
#                                              'BG',
#                                              'BH',
#                                              'BI',
#                                              'BJ',
#                                              'BN',
#                                              'BO',
#                                              'BR',
#                                              'BS',
#                                              'BT',
#                                              'BW',
#                                              'BY',
#                                              'BZ',
#                                              'CA',
#                                              'CD',
#                                              'CG',
#                                              'CH',
#                                              'CI',
#                                              'CL',
#                                              'CM',
#                                              'CO',
#                                              'CR',
#                                              'CV',
#                                              'CW',
#                                              'CY',
#                                              'CZ',
#                                              'DE',
#                                              'DJ',
#                                              'DK',
#                                              'DM',
#                                              'DO',
#                                              'DZ',
#                                              'EC',
#                                              'EE',
#                                              'EG',
#                                              'ES',
#                                              'FI',
#                                              'FJ',
#                                              'FM',
#                                              'FR',
#                                              'GA',
#                                              'GB',
#                                              'GD',
#                                              'GE',
#                                              'GH',
#                                              'GM',
#                                              'GN',
#                                              'GQ',
#                                              'GR',
#                                              'GT',
#                                              'GW',
#                                              'GY',
#                                              'HK',
#                                              'HN',
#                                              'HR',
#                                              'HT',
#                                              'HU',
#                                              'ID',
#                                              'IE',
#                                              'IL',
#                                              'IN',
#                                              'IQ',
#                                              'IS',
#                                              'IT',
#                                              'JM',
#                                              'JO',
#                                              'JP',
#                                              'KE',
#                                              'KG',
#                                              'KH',
#                                              'KI',
#                                              'KM',
#                                              'KN',
#                                              'KR',
#                                              'KW',
#                                              'KZ',
#                                              'LA',
#                                              'LB',
#                                              'LC',
#                                              'LI',
#                                              'LK',
#                                              'LR',
#                                              'LS',
#                                              'LT',
#                                              'LU',
#                                              'LV',
#                                              'LY',
#                                              'MA',
#                                              'MC',
#                                              'MD',
#                                              'ME',
#                                              'MG',
#                                              'MH',
#                                              'MK',
#                                              'ML',
#                                              'MN',
#                                              'MO',
#                                              'MR',
#                                              'MT',
#                                              'MU',
#                                              'MV',
#                                              'MW',
#                                              'MX',
#                                              'MY',
#                                              'MZ',
#                                              'NA',
#                                              'NE',
#                                              'NG',
#                                              'NI',
#                                              'NL',
#                                              'NO',
#                                              'NP',
#                                              'NR',
#                                              'NZ',
#                                              'OM',
#                                              'PA',
#                                              'PE',
#                                              'PG',
#                                              'PH',
#                                              'PK',
#                                              'PL',
#                                              'PS',
#                                              'PT',
#                                              'PW',
#                                              'PY',
#                                              'QA',
#                                              'RO',
#                                              'RS',
#                                              'RU',
#                                              'RW',
#                                              'SA',
#                                              'SB',
#                                              'SC',
#                                              'SE',
#                                              'SG',
#                                              'SI',
#                                              'SK',
#                                              'SL',
#                                              'SM',
#                                              'SN',
#                                              'SR',
#                                              'ST',
#                                              'SV',
#                                              'SZ',
#                                              'TD',
#                                              'TG',
#                                              'TH',
#                                              'TJ',
#                                              'TL',
#                                              'TN',
#                                              'TO',
#                                              'TR',
#                                              'TT',
#                                              'TV',
#                                              'TW',
#                                              'TZ',
#                                              'UA',
#                                              'UG',
#                                              'US',
#                                              'UY',
#                                              'UZ',
#                                              'VC',
#                                              'VE',
#                                              'VN',
#                                              'VU',
#                                              'WS',
#                                              'XK',
#                                              'ZA',
#                                              'ZM',
#                                              'ZW'],
#                        'disc_number': 1,
#                        'duration_ms': 158666,
#                        'explicit': False,
#                        'external_ids': {'isrc': 'FR91U0100008'},
#                        'external_urls': {'spotify': 'https://open.spotify.com/track/6bpmBNPfQ2KFAW0ik6F9Vq'},
#                        'href': 'https://api.spotify.com/v1/tracks/6bpmBNPfQ2KFAW0ik6F9Vq',
#                        'id': '6bpmBNPfQ2KFAW0ik6F9Vq',
#                        'is_local': False,
#                        'name': "La Valse d'Amélie - Version piano",
#                        'popularity': 67,
# ...
#                                              'VN',
#                                              'XK',
#                                              'ZA'],
#                        'disc_number': 1,
#                        'duration_ms': 156560,
#                        'explicit': False,
#                        'external_ids': {'isrc': 'GBF071401810'},
#                        'external_urls': {'spotify': 'https://open.spotify.com/track/24ylgZD6saa4DoFdig8zDW'},
#                        'href': 'https://api.spotify.com/v1/tracks/24ylgZD6saa4DoFdig8zDW',
#                        'id': '24ylgZD6saa4DoFdig8zDW',
#                        'is_local': False,
#                        'name': 'Comptine d’un autre été: L’après-midi',
#                        'popularity': 0,
#                        'preview_url': None,
#                        'track_number': 187,
#                        'type': 'track',
#                        'uri': 'spotify:track:24ylgZD6saa4DoFdig8zDW'},
#                       {'album': {'album_type': 'album',
#                                  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#                                               'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#                                               'id': '0LyfQWJT6nXafLPZqxe9Of',
#                                               'name': 'Various Artists',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#                                  'available_markets': ['AE',
#                                                        'AL',
#                                                        'AR',
#                                                        'AT',
#                                                        'AU',
#                                                        'BA',
#                                                        'BE',
#                                                        'BG',
#                                                        'BH',
#                                                        'BO',
#                                                        'BR',
#                                                        'CA',
#                                                        'CH',
#                                                        'CI',
#                                                        'CL',
#                                                        'CM',
#                                                        'CO',
#                                                        'CR',
#                                                        'CY',
#                                                        'CZ',
#                                                        'DE',
#                                                        'DK',
#                                                        'DO',
#                                                        'DZ',
#                                                        'EC',
#                                                        'EE',
#                                                        'EG',
#                                                        'ES',
#                                                        'FI',
#                                                        'FR',
#                                                        'GB',
#                                                        'GH',
#                                                        'GR',
#                                                        'GT',
#                                                        'HK',
#                                                        'HN',
#                                                        'HR',
#                                                        'HU',
#                                                        'ID',
#                                                        'IE',
#                                                        'IL',
#                                                        'IN',
#                                                        'IS',
#                                                        'IT',
#                                                        'JP',
#                                                        'KE',
#                                                        'KH',
#                                                        'KR',
#                                                        'KW',
#                                                        'LB',
#                                                        'LK',
#                                                        'LT',
#                                                        'LU',
#                                                        'LV',
#                                                        'MA',
#                                                        'ME',
#                                                        'MK',
#                                                        'MT',
#                                                        'MX',
#                                                        'MY',
#                                                        'NG',
#                                                        'NI',
#                                                        'NL',
#                                                        'NO',
#                                                        'NZ',
#                                                        'OM',
#                                                        'PA',
#                                                        'PE',
#                                                        'PH',
#                                                        'PL',
#                                                        'PT',
#                                                        'PY',
#                                                        'QA',
#                                                        'RO',
#                                                        'RS',
#                                                        'SA',
#                                                        'SE',
#                                                        'SG',
#                                                        'SI',
#                                                        'SK',
#                                                        'SN',
#                                                        'SV',
#                                                        'TH',
#                                                        'TN',
#                                                        'TR',
#                                                        'TT',
#                                                        'TW',
#                                                        'UA',
#                                                        'US',
#                                                        'UY',
#                                                        'VE',
#                                                        'VN',
#                                                        'XK',
#                                                        'ZA'],
#                                  'external_urls': {'spotify': 'https://open.spotify.com/album/40X1rALZZjnSwyY6hGQxzk'},
#                                  'href': 'https://api.spotify.com/v1/albums/40X1rALZZjnSwyY6hGQxzk',
#                                  'id': '40X1rALZZjnSwyY6hGQxzk',
#                                  'images': [{'height': 640,
#                                              'url': 'https://i.scdn.co/image/ab67616d0000b273e042ffbe0c5e8da2e630cb02',
#                                              'width': 640},
#                                             {'height': 300,
#                                              'url': 'https://i.scdn.co/image/ab67616d00001e02e042ffbe0c5e8da2e630cb02',
#                                              'width': 300},
#                                             {'height': 64,
#                                              'url': 'https://i.scdn.co/image/ab67616d00004851e042ffbe0c5e8da2e630cb02',
#                                              'width': 64}],
#                                  'name': 'Enjoy Easter Time',
#                                  'release_date': '2022-03-11',
#                                  'release_date_precision': 'day',
#                                  'total_tracks': 57,
#                                  'type': 'album',
#                                  'uri': 'spotify:album:40X1rALZZjnSwyY6hGQxzk'},
#                        'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00sazWvoTLOqg5MFwC68Um'},
#                                     'href': 'https://api.spotify.com/v1/artists/00sazWvoTLOqg5MFwC68Um',
#                                     'id': '00sazWvoTLOqg5MFwC68Um',
#                                     'name': 'Yann Tiersen',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:00sazWvoTLOqg5MFwC68Um'},
#                                    {'external_urls': {'spotify': 'https://open.spotify.com/artist/1ylcY77FWeSVQKh5et1VGp'},
#                                     'href': 'https://api.spotify.com/v1/artists/1ylcY77FWeSVQKh5et1VGp',
#                                     'id': '1ylcY77FWeSVQKh5et1VGp',
#                                     'name': 'Music Lab Collective',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:1ylcY77FWeSVQKh5et1VGp'},
#                                    {'external_urls': {'spotify': 'https://open.spotify.com/artist/0gOrXuu1vCBXe3pwTyb5Ca'},
#                                     'href': 'https://api.spotify.com/v1/artists/0gOrXuu1vCBXe3pwTyb5Ca',
#                                     'id': '0gOrXuu1vCBXe3pwTyb5Ca',
#                                     'name': 'Valentina Lisitsa',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:0gOrXuu1vCBXe3pwTyb5Ca'}],
#                        'available_markets': ['AE',
#                                              'AL',
#                                              'AR',
#                                              'AT',
#                                              'AU',
#                                              'BA',
#                                              'BE',
#                                              'BG',
#                                              'BH',
#                                              'BO',
#                                              'BR',
#                                              'CA',
#                                              'CH',
#                                              'CI',
#                                              'CL',
#                                              'CM',
#                                              'CO',
#                                              'CR',
#                                              'CY',
#                                              'CZ',
#                                              'DE',
#                                              'DK',
#                                              'DO',
#                                              'DZ',
#                                              'EC',
#                                              'EE',
#                                              'EG',
#                                              'ES',
#                                              'FI',
#                                              'FR',
#                                              'GB',
#                                              'GH',
#                                              'GR',
#                                              'GT',
#                                              'HK',
#                                              'HN',
#                                              'HR',
#                                              'HU',
#                                              'ID',
#                                              'IE',
#                                              'IL',
#                                              'IN',
#                                              'IS',
#                                              'IT',
#                                              'JP',
#                                              'KE',
#                                              'KH',
#                                              'KR',
#                                              'KW',
#                                              'LB',
#                                              'LK',
#                                              'LT',
#                                              'LU',
#                                              'LV',
#                                              'MA',
#                                              'ME',
#                                              'MK',
#                                              'MT',
#                                              'MX',
#                                              'MY',
#                                              'NG',
#                                              'NI',
#                                              'NL',
#                                              'NO',
#                                              'NZ',
#                                              'OM',
#                                              'PA',
#                                              'PE',
#                                              'PH',
#                                              'PL',
#                                              'PT',
#                                              'PY',
#                                              'QA',
#                                              'RO',
#                                              'RS',
#                                              'SA',
#                                              'SE',
#                                              'SG',
#                                              'SI',
#                                              'SK',
#                                              'SN',
#                                              'SV',
#                                              'TH',
#                                              'TN',
#                                              'TR',
#                                              'TT',
#                                              'TW',
#                                              'UA',
#                                              'US',
#                                              'UY',
#                                              'VE',
#                                              'VN',
#                                              'XK',
#                                              'ZA'],
#                        'disc_number': 1,
#                        'duration_ms': 156560,
#                        'explicit': False,
#                        'external_ids': {'isrc': 'GBF071401810'},
#                        'external_urls': {'spotify': 'https://open.spotify.com/track/4gXYgWlBHPCJvEIrQ9wwrS'},
#                        'href': 'https://api.spotify.com/v1/tracks/4gXYgWlBHPCJvEIrQ9wwrS',
#                        'id': '4gXYgWlBHPCJvEIrQ9wwrS',
#                        'is_local': False,
#                        'name': 'Comptine d’un autre été: L’après-midi',
#                        'popularity': 1,
#                        'preview_url': None,
#                        'track_number': 5,
#                        'type': 'track',
#                        'uri': 'spotify:track:4gXYgWlBHPCJvEIrQ9wwrS'}],
#             'limit': 5,
#             'next': 'https://api.spotify.com/v1/search?query=Yann+Tiersen&type=track&offset=5&limit=5',
#             'offset': 0,
#             'previous': None,
#             'total': 1222}}

# %%
results['tracks']['items']
# Out:
# [{'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00sazWvoTLOqg5MFwC68Um'},
#      'href': 'https://api.spotify.com/v1/artists/00sazWvoTLOqg5MFwC68Um',
#      'id': '00sazWvoTLOqg5MFwC68Um',
#      'name': 'Yann Tiersen',
#      'type': 'artist',
#      'uri': 'spotify:artist:00sazWvoTLOqg5MFwC68Um'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/6PRPYATK5VvjZ2p911y6U0'},
#    'href': 'https://api.spotify.com/v1/albums/6PRPYATK5VvjZ2p911y6U0',
#    'id': '6PRPYATK5VvjZ2p911y6U0',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2731b7844a8c73c4d48f0bca1de',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e021b7844a8c73c4d48f0bca1de',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048511b7844a8c73c4d48f0bca1de',
#      'width': 64}],
#    'name': "Le Fabuleux destin d'Amélie Poulain (Bande originale du film)",
#    'release_date': '2001-04-23',
#    'release_date_precision': 'day',
#    'total_tracks': 15,
#    'type': 'album',
#    'uri': 'spotify:album:6PRPYATK5VvjZ2p911y6U0'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00sazWvoTLOqg5MFwC68Um'},
#     'href': 'https://api.spotify.com/v1/artists/00sazWvoTLOqg5MFwC68Um',
#     'id': '00sazWvoTLOqg5MFwC68Um',
#     'name': 'Yann Tiersen',
#     'type': 'artist',
#     'uri': 'spotify:artist:00sazWvoTLOqg5MFwC68Um'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CD',
#    'CG',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IQ',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'LY',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RU',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TJ',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VE',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'disc_number': 1,
#   'duration_ms': 140733,
#   'explicit': False,
#   'external_ids': {'isrc': 'FR91U0100002'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/14rZjW3RioG7WesZhYESso'},
#   'href': 'https://api.spotify.com/v1/tracks/14rZjW3RioG7WesZhYESso',
#   'id': '14rZjW3RioG7WesZhYESso',
#   'is_local': False,
#   'name': "Comptine d'un autre été, l'après-midi",
#   'popularity': 77,
#   'preview_url': 'https://p.scdn.co/mp3-preview/c3395706db3ffb40a9fefd855141fbad15f78881?cid=0912c34e16c349f28a330c0eba3cc52f',
#   'track_number': 3,
#   'type': 'track',
#   'uri': 'spotify:track:14rZjW3RioG7WesZhYESso'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00sazWvoTLOqg5MFwC68Um'},
#      'href': 'https://api.spotify.com/v1/artists/00sazWvoTLOqg5MFwC68Um',
#      'id': '00sazWvoTLOqg5MFwC68Um',
#      'name': 'Yann Tiersen',
#      'type': 'artist',
#      'uri': 'spotify:artist:00sazWvoTLOqg5MFwC68Um'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/6PRPYATK5VvjZ2p911y6U0'},
#    'href': 'https://api.spotify.com/v1/albums/6PRPYATK5VvjZ2p911y6U0',
#    'id': '6PRPYATK5VvjZ2p911y6U0',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2731b7844a8c73c4d48f0bca1de',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e021b7844a8c73c4d48f0bca1de',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048511b7844a8c73c4d48f0bca1de',
#      'width': 64}],
#    'name': "Le Fabuleux destin d'Amélie Poulain (Bande originale du film)",
#    'release_date': '2001-04-23',
#    'release_date_precision': 'day',
#    'total_tracks': 15,
#    'type': 'album',
#    'uri': 'spotify:album:6PRPYATK5VvjZ2p911y6U0'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00sazWvoTLOqg5MFwC68Um'},
#     'href': 'https://api.spotify.com/v1/artists/00sazWvoTLOqg5MFwC68Um',
#     'id': '00sazWvoTLOqg5MFwC68Um',
#     'name': 'Yann Tiersen',
#     'type': 'artist',
#     'uri': 'spotify:artist:00sazWvoTLOqg5MFwC68Um'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CD',
#    'CG',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IQ',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'LY',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RU',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TJ',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VE',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'disc_number': 1,
#   'duration_ms': 158666,
#   'explicit': False,
#   'external_ids': {'isrc': 'FR91U0100008'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/6bpmBNPfQ2KFAW0ik6F9Vq'},
#   'href': 'https://api.spotify.com/v1/tracks/6bpmBNPfQ2KFAW0ik6F9Vq',
#   'id': '6bpmBNPfQ2KFAW0ik6F9Vq',
#   'is_local': False,
#   'name': "La Valse d'Amélie - Version piano",
#   'popularity': 67,
#   'preview_url': 'https://p.scdn.co/mp3-preview/273992bc4da8b34a3bd931de90f72a918c8f7fdd?cid=0912c34e16c349f28a330c0eba3cc52f',
#   'track_number': 10,
#   'type': 'track',
#   'uri': 'spotify:track:6bpmBNPfQ2KFAW0ik6F9Vq'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#      'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#      'id': '0LyfQWJT6nXafLPZqxe9Of',
#      'name': 'Various Artists',
#      'type': 'artist',
#      'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#    'available_markets': ['AE',
#     'AL',
#     'AR',
#     'AT',
#     'AU',
#     'BA',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GH',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HR',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JP',
#     'KE',
#     'KH',
#     'KR',
#     'KW',
#     'LB',
#     'LK',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'ME',
#     'MK',
#     'MT',
#     'MX',
#     'MY',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'SA',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SN',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TT',
#     'TW',
#     'UA',
#     'US',
#     'UY',
#     'VE',
#     'VN',
#     'XK',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/3UlHVFGJXAQzfLFPgEATkv'},
#    'href': 'https://api.spotify.com/v1/albums/3UlHVFGJXAQzfLFPgEATkv',
#    'id': '3UlHVFGJXAQzfLFPgEATkv',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b27344f04044b11351867db15022',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e0244f04044b11351867db15022',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d0000485144f04044b11351867db15022',
#      'width': 64}],
#    'name': 'Dolce dormire classic relaxing piano',
#    'release_date': '2022-03-16',
#    'release_date_precision': 'day',
#    'total_tracks': 52,
#    'type': 'album',
#    'uri': 'spotify:album:3UlHVFGJXAQzfLFPgEATkv'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00sazWvoTLOqg5MFwC68Um'},
#     'href': 'https://api.spotify.com/v1/artists/00sazWvoTLOqg5MFwC68Um',
#     'id': '00sazWvoTLOqg5MFwC68Um',
#     'name': 'Yann Tiersen',
#     'type': 'artist',
#     'uri': 'spotify:artist:00sazWvoTLOqg5MFwC68Um'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/1ylcY77FWeSVQKh5et1VGp'},
#     'href': 'https://api.spotify.com/v1/artists/1ylcY77FWeSVQKh5et1VGp',
#     'id': '1ylcY77FWeSVQKh5et1VGp',
#     'name': 'Music Lab Collective',
#     'type': 'artist',
#     'uri': 'spotify:artist:1ylcY77FWeSVQKh5et1VGp'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/0gOrXuu1vCBXe3pwTyb5Ca'},
#     'href': 'https://api.spotify.com/v1/artists/0gOrXuu1vCBXe3pwTyb5Ca',
#     'id': '0gOrXuu1vCBXe3pwTyb5Ca',
#     'name': 'Valentina Lisitsa',
#     'type': 'artist',
#     'uri': 'spotify:artist:0gOrXuu1vCBXe3pwTyb5Ca'}],
#   'available_markets': ['AE',
#    'AL',
#    'AR',
#    'AT',
#    'AU',
#    'BA',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'CA',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GH',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HR',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JP',
#    'KE',
#    'KH',
#    'KR',
#    'KW',
#    'LB',
#    'LK',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'ME',
#    'MK',
#    'MT',
#    'MX',
#    'MY',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'SA',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SN',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TT',
#    'TW',
#    'UA',
#    'US',
#    'UY',
#    'VE',
#    'VN',
#    'XK',
#    'ZA'],
#   'disc_number': 1,
#   'duration_ms': 156560,
#   'explicit': False,
#   'external_ids': {'isrc': 'GBF071401810'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/4pZ3z8fTyFlg7txomZi3OY'},
#   'href': 'https://api.spotify.com/v1/tracks/4pZ3z8fTyFlg7txomZi3OY',
#   'id': '4pZ3z8fTyFlg7txomZi3OY',
#   'is_local': False,
#   'name': 'Comptine d’un autre été: L’après-midi',
#   'popularity': 4,
#   'preview_url': None,
#   'track_number': 4,
#   'type': 'track',
#   'uri': 'spotify:track:4pZ3z8fTyFlg7txomZi3OY'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#      'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#      'id': '0LyfQWJT6nXafLPZqxe9Of',
#      'name': 'Various Artists',
#      'type': 'artist',
#      'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#    'available_markets': ['AE',
#     'AL',
#     'AR',
#     'AT',
#     'AU',
#     'BA',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GH',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HR',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JP',
#     'KE',
#     'KH',
#     'KR',
#     'KW',
#     'LB',
#     'LK',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'ME',
#     'MK',
#     'MT',
#     'MX',
#     'MY',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'SA',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SN',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TT',
#     'TW',
#     'UA',
#     'US',
#     'UY',
#     'VE',
#     'VN',
#     'XK',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/777R3zysBRXTylrmWJ0Jhx'},
#    'href': 'https://api.spotify.com/v1/albums/777R3zysBRXTylrmWJ0Jhx',
#    'id': '777R3zysBRXTylrmWJ0Jhx',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b27337a55584df5b8c31b0a252d6',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e0237a55584df5b8c31b0a252d6',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d0000485137a55584df5b8c31b0a252d6',
#      'width': 64}],
#    'name': 'Sleepy Piano Music',
#    'release_date': '2022-03-18',
#    'release_date_precision': 'day',
#    'total_tracks': 397,
#    'type': 'album',
#    'uri': 'spotify:album:777R3zysBRXTylrmWJ0Jhx'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00sazWvoTLOqg5MFwC68Um'},
#     'href': 'https://api.spotify.com/v1/artists/00sazWvoTLOqg5MFwC68Um',
#     'id': '00sazWvoTLOqg5MFwC68Um',
#     'name': 'Yann Tiersen',
#     'type': 'artist',
#     'uri': 'spotify:artist:00sazWvoTLOqg5MFwC68Um'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/1ylcY77FWeSVQKh5et1VGp'},
#     'href': 'https://api.spotify.com/v1/artists/1ylcY77FWeSVQKh5et1VGp',
#     'id': '1ylcY77FWeSVQKh5et1VGp',
#     'name': 'Music Lab Collective',
#     'type': 'artist',
#     'uri': 'spotify:artist:1ylcY77FWeSVQKh5et1VGp'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/0gOrXuu1vCBXe3pwTyb5Ca'},
#     'href': 'https://api.spotify.com/v1/artists/0gOrXuu1vCBXe3pwTyb5Ca',
#     'id': '0gOrXuu1vCBXe3pwTyb5Ca',
#     'name': 'Valentina Lisitsa',
#     'type': 'artist',
#     'uri': 'spotify:artist:0gOrXuu1vCBXe3pwTyb5Ca'}],
#   'available_markets': ['AE',
#    'AL',
#    'AR',
#    'AT',
#    'AU',
#    'BA',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'CA',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GH',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HR',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JP',
#    'KE',
#    'KH',
#    'KR',
#    'KW',
#    'LB',
#    'LK',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'ME',
#    'MK',
#    'MT',
#    'MX',
#    'MY',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'SA',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SN',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TT',
#    'TW',
#    'UA',
#    'US',
#    'UY',
#    'VE',
#    'VN',
#    'XK',
#    'ZA'],
#   'disc_number': 1,
#   'duration_ms': 156560,
#   'explicit': False,
#   'external_ids': {'isrc': 'GBF071401810'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/24ylgZD6saa4DoFdig8zDW'},
#   'href': 'https://api.spotify.com/v1/tracks/24ylgZD6saa4DoFdig8zDW',
#   'id': '24ylgZD6saa4DoFdig8zDW',
#   'is_local': False,
#   'name': 'Comptine d’un autre été: L’après-midi',
#   'popularity': 0,
#   'preview_url': None,
#   'track_number': 187,
#   'type': 'track',
#   'uri': 'spotify:track:24ylgZD6saa4DoFdig8zDW'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#      'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#      'id': '0LyfQWJT6nXafLPZqxe9Of',
#      'name': 'Various Artists',
#      'type': 'artist',
#      'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#    'available_markets': ['AE',
#     'AL',
#     'AR',
#     'AT',
#     'AU',
#     'BA',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GH',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HR',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JP',
#     'KE',
#     'KH',
#     'KR',
#     'KW',
#     'LB',
#     'LK',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'ME',
#     'MK',
#     'MT',
#     'MX',
#     'MY',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'SA',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SN',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TT',
#     'TW',
#     'UA',
#     'US',
#     'UY',
#     'VE',
#     'VN',
#     'XK',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/40X1rALZZjnSwyY6hGQxzk'},
#    'href': 'https://api.spotify.com/v1/albums/40X1rALZZjnSwyY6hGQxzk',
#    'id': '40X1rALZZjnSwyY6hGQxzk',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273e042ffbe0c5e8da2e630cb02',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02e042ffbe0c5e8da2e630cb02',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851e042ffbe0c5e8da2e630cb02',
#      'width': 64}],
#    'name': 'Enjoy Easter Time',
#    'release_date': '2022-03-11',
#    'release_date_precision': 'day',
#    'total_tracks': 57,
#    'type': 'album',
#    'uri': 'spotify:album:40X1rALZZjnSwyY6hGQxzk'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00sazWvoTLOqg5MFwC68Um'},
#     'href': 'https://api.spotify.com/v1/artists/00sazWvoTLOqg5MFwC68Um',
#     'id': '00sazWvoTLOqg5MFwC68Um',
#     'name': 'Yann Tiersen',
#     'type': 'artist',
#     'uri': 'spotify:artist:00sazWvoTLOqg5MFwC68Um'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/1ylcY77FWeSVQKh5et1VGp'},
#     'href': 'https://api.spotify.com/v1/artists/1ylcY77FWeSVQKh5et1VGp',
#     'id': '1ylcY77FWeSVQKh5et1VGp',
#     'name': 'Music Lab Collective',
#     'type': 'artist',
#     'uri': 'spotify:artist:1ylcY77FWeSVQKh5et1VGp'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/0gOrXuu1vCBXe3pwTyb5Ca'},
#     'href': 'https://api.spotify.com/v1/artists/0gOrXuu1vCBXe3pwTyb5Ca',
#     'id': '0gOrXuu1vCBXe3pwTyb5Ca',
#     'name': 'Valentina Lisitsa',
#     'type': 'artist',
#     'uri': 'spotify:artist:0gOrXuu1vCBXe3pwTyb5Ca'}],
#   'available_markets': ['AE',
#    'AL',
#    'AR',
#    'AT',
#    'AU',
#    'BA',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'CA',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GH',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HR',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JP',
#    'KE',
#    'KH',
#    'KR',
#    'KW',
#    'LB',
#    'LK',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'ME',
#    'MK',
#    'MT',
#    'MX',
#    'MY',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'SA',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SN',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TT',
#    'TW',
#    'UA',
#    'US',
#    'UY',
#    'VE',
#    'VN',
#    'XK',
#    'ZA'],
#   'disc_number': 1,
#   'duration_ms': 156560,
#   'explicit': False,
#   'external_ids': {'isrc': 'GBF071401810'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/4gXYgWlBHPCJvEIrQ9wwrS'},
#   'href': 'https://api.spotify.com/v1/tracks/4gXYgWlBHPCJvEIrQ9wwrS',
#   'id': '4gXYgWlBHPCJvEIrQ9wwrS',
#   'is_local': False,
#   'name': 'Comptine d’un autre été: L’après-midi',
#   'popularity': 1,
#   'preview_url': None,
#   'track_number': 5,
#   'type': 'track',
#   'uri': 'spotify:track:4gXYgWlBHPCJvEIrQ9wwrS'}]

# %%
len(results['tracks']['items'])
# Out:
# 5

# %%
results['tracks']['items'][0]
# Out:
# {'album': {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00sazWvoTLOqg5MFwC68Um'},
#     'href': 'https://api.spotify.com/v1/artists/00sazWvoTLOqg5MFwC68Um',
#     'id': '00sazWvoTLOqg5MFwC68Um',
#     'name': 'Yann Tiersen',
#     'type': 'artist',
#     'uri': 'spotify:artist:00sazWvoTLOqg5MFwC68Um'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CD',
#    'CG',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IQ',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'LY',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RU',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TJ',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VE',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/6PRPYATK5VvjZ2p911y6U0'},
#   'href': 'https://api.spotify.com/v1/albums/6PRPYATK5VvjZ2p911y6U0',
#   'id': '6PRPYATK5VvjZ2p911y6U0',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2731b7844a8c73c4d48f0bca1de',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e021b7844a8c73c4d48f0bca1de',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048511b7844a8c73c4d48f0bca1de',
#     'width': 64}],
#   'name': "Le Fabuleux destin d'Amélie Poulain (Bande originale du film)",
#   'release_date': '2001-04-23',
#   'release_date_precision': 'day',
#   'total_tracks': 15,
#   'type': 'album',
#   'uri': 'spotify:album:6PRPYATK5VvjZ2p911y6U0'},
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00sazWvoTLOqg5MFwC68Um'},
#    'href': 'https://api.spotify.com/v1/artists/00sazWvoTLOqg5MFwC68Um',
#    'id': '00sazWvoTLOqg5MFwC68Um',
#    'name': 'Yann Tiersen',
#    'type': 'artist',
#    'uri': 'spotify:artist:00sazWvoTLOqg5MFwC68Um'}],
#  'available_markets': ['AD',
#   'AE',
#   'AG',
#   'AL',
#   'AM',
#   'AO',
#   'AR',
#   'AT',
#   'AU',
#   'AZ',
#   'BA',
#   'BB',
#   'BD',
#   'BE',
#   'BF',
#   'BG',
#   'BH',
#   'BI',
#   'BJ',
#   'BN',
#   'BO',
#   'BR',
#   'BS',
#   'BT',
#   'BW',
#   'BY',
#   'BZ',
#   'CA',
#   'CD',
#   'CG',
#   'CH',
#   'CI',
#   'CL',
#   'CM',
#   'CO',
#   'CR',
#   'CV',
#   'CW',
#   'CY',
#   'CZ',
#   'DE',
#   'DJ',
#   'DK',
#   'DM',
#   'DO',
#   'DZ',
#   'EC',
#   'EE',
#   'EG',
#   'ES',
#   'FI',
#   'FJ',
#   'FM',
#   'FR',
#   'GA',
#   'GB',
#   'GD',
#   'GE',
#   'GH',
#   'GM',
#   'GN',
#   'GQ',
#   'GR',
#   'GT',
#   'GW',
#   'GY',
#   'HK',
#   'HN',
#   'HR',
#   'HT',
#   'HU',
#   'ID',
#   'IE',
#   'IL',
#   'IN',
#   'IQ',
#   'IS',
#   'IT',
#   'JM',
#   'JO',
#   'JP',
#   'KE',
#   'KG',
#   'KH',
#   'KI',
#   'KM',
#   'KN',
#   'KR',
#   'KW',
#   'KZ',
#   'LA',
#   'LB',
#   'LC',
#   'LI',
#   'LK',
#   'LR',
#   'LS',
#   'LT',
#   'LU',
#   'LV',
#   'LY',
#   'MA',
#   'MC',
#   'MD',
#   'ME',
#   'MG',
#   'MH',
#   'MK',
#   'ML',
#   'MN',
#   'MO',
#   'MR',
#   'MT',
#   'MU',
#   'MV',
#   'MW',
#   'MX',
#   'MY',
#   'MZ',
#   'NA',
#   'NE',
#   'NG',
#   'NI',
#   'NL',
#   'NO',
#   'NP',
#   'NR',
#   'NZ',
#   'OM',
#   'PA',
#   'PE',
#   'PG',
#   'PH',
#   'PK',
#   'PL',
#   'PS',
#   'PT',
#   'PW',
#   'PY',
#   'QA',
#   'RO',
#   'RS',
#   'RU',
#   'RW',
#   'SA',
#   'SB',
#   'SC',
#   'SE',
#   'SG',
#   'SI',
#   'SK',
#   'SL',
#   'SM',
#   'SN',
#   'SR',
#   'ST',
#   'SV',
#   'SZ',
#   'TD',
#   'TG',
#   'TH',
#   'TJ',
#   'TL',
#   'TN',
#   'TO',
#   'TR',
#   'TT',
#   'TV',
#   'TW',
#   'TZ',
#   'UA',
#   'UG',
#   'US',
#   'UY',
#   'UZ',
#   'VC',
#   'VE',
#   'VN',
#   'VU',
#   'WS',
#   'XK',
#   'ZA',
#   'ZM',
#   'ZW'],
#  'disc_number': 1,
#  'duration_ms': 140733,
#  'explicit': False,
#  'external_ids': {'isrc': 'FR91U0100002'},
#  'external_urls': {'spotify': 'https://open.spotify.com/track/14rZjW3RioG7WesZhYESso'},
#  'href': 'https://api.spotify.com/v1/tracks/14rZjW3RioG7WesZhYESso',
#  'id': '14rZjW3RioG7WesZhYESso',
#  'is_local': False,
#  'name': "Comptine d'un autre été, l'après-midi",
#  'popularity': 77,
#  'preview_url': 'https://p.scdn.co/mp3-preview/c3395706db3ffb40a9fefd855141fbad15f78881?cid=0912c34e16c349f28a330c0eba3cc52f',
#  'track_number': 3,
#  'type': 'track',
#  'uri': 'spotify:track:14rZjW3RioG7WesZhYESso'}

# %%
results['tracks']['items'][0].keys()
# Out:
# dict_keys(['album', 'artists', 'available_markets', 'disc_number', 'duration_ms', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'name', 'popularity', 'preview_url', 'track_number', 'type', 'uri'])

# %%
results['tracks']['items'][0]['id']
# Out:
# '14rZjW3RioG7WesZhYESso'

# %%
for item in results['tracks']['items']:
    print("The name of song is: '{}' and the id is: {}".format(item['name'],item['external_urls']['spotify']))
# Out:
# The name of song is: 'Comptine d'un autre été, l'après-midi' and the id is: https://open.spotify.com/track/14rZjW3RioG7WesZhYESso
# The name of song is: 'La Valse d'Amélie - Version piano' and the id is: https://open.spotify.com/track/6bpmBNPfQ2KFAW0ik6F9Vq
# The name of song is: 'Comptine d’un autre été: L’après-midi' and the id is: https://open.spotify.com/track/4pZ3z8fTyFlg7txomZi3OY
# The name of song is: 'Comptine d’un autre été: L’après-midi' and the id is: https://open.spotify.com/track/24ylgZD6saa4DoFdig8zDW
# The name of song is: 'Comptine d’un autre été: L’après-midi' and the id is: https://open.spotify.com/track/4gXYgWlBHPCJvEIrQ9wwrS

# %%
results["tracks"]["items"][0]['name']
# Out:
# "Comptine d'un autre été, l'après-midi"

# %%
import pandas as pd

song = sp.search(q="comptine d'un autre été", limit=1) 
#pprint.pprint(song['tracks']['items'][0]['uri'])
song["tracks"]["items"][0]["uri"]
sp.audio_features(song["tracks"]["items"][0]["uri"])[0]
my_dict = sp.audio_features(song["tracks"]["items"][0]["uri"])[0] # you can provide a list of uri's

print(my_dict)
my_dict_new = { key: [my_dict[key]] for key in list(my_dict.keys()) }
#my_dict_new['name'] = [song["tracks"]["items"][0]['name']]
print(my_dict_new)

pd.DataFrame(my_dict_new)
# Out:
# {'danceability': 0.483, 'energy': 0.192, 'key': 4, 'loudness': -15.378, 'mode': 0, 'speechiness': 0.0469, 'acousticness': 0.991, 'instrumentalness': 0.908, 'liveness': 0.106, 'valence': 0.0542, 'tempo': 100.848, 'type': 'audio_features', 'id': '14rZjW3RioG7WesZhYESso', 'uri': 'spotify:track:14rZjW3RioG7WesZhYESso', 'track_href': 'https://api.spotify.com/v1/tracks/14rZjW3RioG7WesZhYESso', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/14rZjW3RioG7WesZhYESso', 'duration_ms': 140733, 'time_signature': 4}
# {'danceability': [0.483], 'energy': [0.192], 'key': [4], 'loudness': [-15.378], 'mode': [0], 'speechiness': [0.0469], 'acousticness': [0.991], 'instrumentalness': [0.908], 'liveness': [0.106], 'valence': [0.0542], 'tempo': [100.848], 'type': ['audio_features'], 'id': ['14rZjW3RioG7WesZhYESso'], 'uri': ['spotify:track:14rZjW3RioG7WesZhYESso'], 'track_href': ['https://api.spotify.com/v1/tracks/14rZjW3RioG7WesZhYESso'], 'analysis_url': ['https://api.spotify.com/v1/audio-analysis/14rZjW3RioG7WesZhYESso'], 'duration_ms': [140733], 'time_signature': [4]}
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.483   0.192    4   -15.378     0       0.0469         0.991
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0             0.908     0.106   0.0542  100.848  audio_features
#
#                        id                                   uri  \
# 0  14rZjW3RioG7WesZhYESso  spotify:track:14rZjW3RioG7WesZhYESso
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/14rZjW3RioG7...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/14rZ...       140733
#
#    time_signature
# 0               4

# %% [markdown]
# The meaning of Spotify audio features can be found [here](https://developer.spotify.com/discover/) and [here](https://www.therecordindustry.io/spotify-audio-features/)

# %% [markdown]
# Let's search for songs of several artists

# %%
my_artists = ['Placebo','Marylin Manson','Janis Joplin']

my_dict = {}
#for artist in my_artists:
#    #result = sp.search(q=artist, limit= 50)
#    my_dict[artist] = sp.search(q=artist, limit= 50)

my_dict = {artist: sp.search(q=artist, limit= 50) for artist in my_artists}
#my_dict
my_dict.keys()
# Out:
# dict_keys(['Placebo', 'Marylin Manson', 'Janis Joplin'])

# %%
len(my_dict['Janis Joplin']['tracks']['items'])
# Out:
# 50

# %%
type(my_dict['Janis Joplin']['tracks']['items'][0])
# Out:
# dict

# %%
my_dict['Janis Joplin']['tracks']['items'][0].keys()
# Out:
# dict_keys(['album', 'artists', 'available_markets', 'disc_number', 'duration_ms', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'name', 'popularity', 'preview_url', 'track_number', 'type', 'uri'])

# %% [markdown]
# # Understanding the json

# %% [markdown]
# Understanding the hierachy of a JSON can make you mad. Therefore you may want to consider using some online pages where you can paste your JSON file and see the "tree" structure of the file.
#
# https://codebeautify.org/jsonviewer
#
# So, copy the json output from the previous query and paste it on the website's left panel. On the right panel you will be able to see the hierachy of the json file.

# %% [markdown]
# Let's get used to the json at hand.

# %%
print("The json file has the following keys: ",list(results.keys())) # We can see that we only have tracks
print("The 'tracks' key has the following child keys: ",list(results["tracks"].keys())) # Let's check the values
print("The query we made is: ",results["tracks"]["href"]) # Query we have searched 
print("The song's info is contained in: ",results["tracks"]["items"]) #items (actual tracks)
print("The limit of the query we've made is: ",results["tracks"]["limit"]) #Limit we have chosen
print("The next page if any: ",results["tracks"]["next"]) #link to the next page (next 50 tracks)
print("The starting webpage: ",results["tracks"]["offset"]) # Actual offset (starting point)
print("Starting webpage: ",results["tracks"]["previous"]) #Previous search
print("Total number of results: ",results["tracks"]["total"]) # Number of matches
# Out:
# The json file has the following keys:  ['tracks']
# The 'tracks' key has the following child keys:  ['href', 'items', 'limit', 'next', 'offset', 'previous', 'total']
# The query we made is:  https://api.spotify.com/v1/search?query=Yann+Tiersen&type=track&offset=0&limit=5
# The song's info is contained in:  [{'album': {'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00sazWvoTLOqg5MFwC68Um'}, 'href': 'https://api.spotify.com/v1/artists/00sazWvoTLOqg5MFwC68Um', 'id': '00sazWvoTLOqg5MFwC68Um', 'name': 'Yann Tiersen', 'type': 'artist', 'uri': 'spotify:artist:00sazWvoTLOqg5MFwC68Um'}], 'available_markets': ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT', 'AU', 'AZ', 'BA', 'BB', 'BD', 'BE', 'BF', 'BG', 'BH', 'BI', 'BJ', 'BN', 'BO', 'BR', 'BS', 'BT', 'BW', 'BY', 'BZ', 'CA', 'CD', 'CG', 'CH', 'CI', 'CL', 'CM', 'CO', 'CR', 'CV', 'CW', 'CY', 'CZ', 'DE', 'DJ', 'DK', 'DM', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FJ', 'FM', 'FR', 'GA', 'GB', 'GD', 'GE', 'GH', 'GM', 'GN', 'GQ', 'GR', 'GT', 'GW', 'GY', 'HK', 'HN', 'HR', 'HT', 'HU', 'ID', 'IE', 'IL', 'IN', 'IQ', 'IS', 'IT', 'JM', 'JO', 'JP', 'KE', 'KG', 'KH', 'KI', 'KM', 'KN', 'KR', 'KW', 'KZ', 'LA', 'LB', 'LC', 'LI', 'LK', 'LR', 'LS', 'LT', 'LU', 'LV', 'LY', 'MA', 'MC', 'MD', 'ME', 'MG', 'MH', 'MK', 'ML', 'MN', 'MO', 'MR', 'MT', 'MU', 'MV', 'MW', 'MX', 'MY', 'MZ', 'NA', 'NE', 'NG', 'NI', 'NL', 'NO', 'NP', 'NR', 'NZ', 'OM', 'PA', 'PE', 'PG', 'PH', 'PK', 'PL', 'PS', 'PT', 'PW', 'PY', 'QA', 'RO', 'RS', 'RU', 'RW', 'SA', 'SB', 'SC', 'SE', 'SG', 'SI', 'SK', 'SL', 'SM', 'SN', 'SR', 'ST', 'SV', 'SZ', 'TD', 'TG', 'TH', 'TJ', 'TL', 'TN', 'TO', 'TR', 'TT', 'TV', 'TW', 'TZ', 'UA', 'UG', 'US', 'UY', 'UZ', 'VC', 'VE', 'VN', 'VU', 'WS', 'XK', 'ZA', 'ZM', 'ZW'], 'external_urls': {'spotify': 'https://open.spotify.com/album/6PRPYATK5VvjZ2p911y6U0'}, 'href': 'https://api.spotify.com/v1/albums/6PRPYATK5VvjZ2p911y6U0', 'id': '6PRPYATK5VvjZ2p911y6U0', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b2731b7844a8c73c4d48f0bca1de', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e021b7844a8c73c4d48f0bca1de', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d000048511b7844a8c73c4d48f0bca1de', 'width': 64}], 'name': "Le Fabuleux destin d'Amélie Poulain (Bande originale du film)", 'release_date': '2001-04-23', 'release_date_precision': 'day', 'total_tracks': 15, 'type': 'album', 'uri': 'spotify:album:6PRPYATK5VvjZ2p911y6U0'}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00sazWvoTLOqg5MFwC68Um'}, 'href': 'https://api.spotify.com/v1/artists/00sazWvoTLOqg5MFwC68Um', 'id': '00sazWvoTLOqg5MFwC68Um', 'name': 'Yann Tiersen', 'type': 'artist', 'uri': 'spotify:artist:00sazWvoTLOqg5MFwC68Um'}], 'available_markets': ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT', 'AU', 'AZ', 'BA', 'BB', 'BD', 'BE', 'BF', 'BG', 'BH', 'BI', 'BJ', 'BN', 'BO', 'BR', 'BS', 'BT', 'BW', 'BY', 'BZ', 'CA', 'CD', 'CG', 'CH', 'CI', 'CL', 'CM', 'CO', 'CR', 'CV', 'CW', 'CY', 'CZ', 'DE', 'DJ', 'DK', 'DM', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FJ', 'FM', 'FR', 'GA', 'GB', 'GD', 'GE', 'GH', 'GM', 'GN', 'GQ', 'GR', 'GT', 'GW', 'GY', 'HK', 'HN', 'HR', 'HT', 'HU', 'ID', 'IE', 'IL', 'IN', 'IQ', 'IS', 'IT', 'JM', 'JO', 'JP', 'KE', 'KG', 'KH', 'KI', 'KM', 'KN', 'KR', 'KW', 'KZ', 'LA', 'LB', 'LC', 'LI', 'LK', 'LR', 'LS', 'LT', 'LU', 'LV', 'LY', 'MA', 'MC', 'MD', 'ME', 'MG', 'MH', 'MK', 'ML', 'MN', 'MO', 'MR', 'MT', 'MU', 'MV', 'MW', 'MX', 'MY', 'MZ', 'NA', 'NE', 'NG', 'NI', 'NL', 'NO', 'NP', 'NR', 'NZ', 'OM', 'PA', 'PE', 'PG', 'PH', 'PK', 'PL', 'PS', 'PT', 'PW', 'PY', 'QA', 'RO', 'RS', 'RU', 'RW', 'SA', 'SB', 'SC', 'SE', 'SG', 'SI', 'SK', 'SL', 'SM', 'SN', 'SR', 'ST', 'SV', 'SZ', 'TD', 'TG', 'TH', 'TJ', 'TL', 'TN', 'TO', 'TR', 'TT', 'TV', 'TW', 'TZ', 'UA', 'UG', 'US', 'UY', 'UZ', 'VC', 'VE', 'VN', 'VU', 'WS', 'XK', 'ZA', 'ZM', 'ZW'], 'disc_number': 1, 'duration_ms': 140733, 'explicit': False, 'external_ids': {'isrc': 'FR91U0100002'}, 'external_urls': {'spotify': 'https://open.spotify.com/track/14rZjW3RioG7WesZhYESso'}, 'href': 'https://api.spotify.com/v1/tracks/14rZjW3RioG7WesZhYESso', 'id': '14rZjW3RioG7WesZhYESso', 'is_local': False, 'name': "Comptine d'un autre été, l'après-mid ...
# The limit of the query we've made is:  5
# The next page if any:  https://api.spotify.com/v1/search?query=Yann+Tiersen&type=track&offset=5&limit=5
# The starting webpage:  0
# Starting webpage:  None
# Total number of results:  1222

# %% [markdown]
# ## Exploring the tracks

# %%
print("Total number of tracks: ",len(results["tracks"]["items"])) # 50 Tracks (as limited, it is the maximum)
print("Info of the first song: ",results["tracks"]["items"][0]) # Explore the first song 
print("The keys of the dictionary are: ",list(results["tracks"]["items"][0].keys())) # We will focus on album, artists, id, name, popularity, type and uri
# Out:
# Total number of tracks:  5
# Info of the first song:  {'album': {'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00sazWvoTLOqg5MFwC68Um'}, 'href': 'https://api.spotify.com/v1/artists/00sazWvoTLOqg5MFwC68Um', 'id': '00sazWvoTLOqg5MFwC68Um', 'name': 'Yann Tiersen', 'type': 'artist', 'uri': 'spotify:artist:00sazWvoTLOqg5MFwC68Um'}], 'available_markets': ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT', 'AU', 'AZ', 'BA', 'BB', 'BD', 'BE', 'BF', 'BG', 'BH', 'BI', 'BJ', 'BN', 'BO', 'BR', 'BS', 'BT', 'BW', 'BY', 'BZ', 'CA', 'CD', 'CG', 'CH', 'CI', 'CL', 'CM', 'CO', 'CR', 'CV', 'CW', 'CY', 'CZ', 'DE', 'DJ', 'DK', 'DM', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FJ', 'FM', 'FR', 'GA', 'GB', 'GD', 'GE', 'GH', 'GM', 'GN', 'GQ', 'GR', 'GT', 'GW', 'GY', 'HK', 'HN', 'HR', 'HT', 'HU', 'ID', 'IE', 'IL', 'IN', 'IQ', 'IS', 'IT', 'JM', 'JO', 'JP', 'KE', 'KG', 'KH', 'KI', 'KM', 'KN', 'KR', 'KW', 'KZ', 'LA', 'LB', 'LC', 'LI', 'LK', 'LR', 'LS', 'LT', 'LU', 'LV', 'LY', 'MA', 'MC', 'MD', 'ME', 'MG', 'MH', 'MK', 'ML', 'MN', 'MO', 'MR', 'MT', 'MU', 'MV', 'MW', 'MX', 'MY', 'MZ', 'NA', 'NE', 'NG', 'NI', 'NL', 'NO', 'NP', 'NR', 'NZ', 'OM', 'PA', 'PE', 'PG', 'PH', 'PK', 'PL', 'PS', 'PT', 'PW', 'PY', 'QA', 'RO', 'RS', 'RU', 'RW', 'SA', 'SB', 'SC', 'SE', 'SG', 'SI', 'SK', 'SL', 'SM', 'SN', 'SR', 'ST', 'SV', 'SZ', 'TD', 'TG', 'TH', 'TJ', 'TL', 'TN', 'TO', 'TR', 'TT', 'TV', 'TW', 'TZ', 'UA', 'UG', 'US', 'UY', 'UZ', 'VC', 'VE', 'VN', 'VU', 'WS', 'XK', 'ZA', 'ZM', 'ZW'], 'external_urls': {'spotify': 'https://open.spotify.com/album/6PRPYATK5VvjZ2p911y6U0'}, 'href': 'https://api.spotify.com/v1/albums/6PRPYATK5VvjZ2p911y6U0', 'id': '6PRPYATK5VvjZ2p911y6U0', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b2731b7844a8c73c4d48f0bca1de', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e021b7844a8c73c4d48f0bca1de', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d000048511b7844a8c73c4d48f0bca1de', 'width': 64}], 'name': "Le Fabuleux destin d'Amélie Poulain (Bande originale du film)", 'release_date': '2001-04-23', 'release_date_precision': 'day', 'total_tracks': 15, 'type': 'album', 'uri': 'spotify:album:6PRPYATK5VvjZ2p911y6U0'}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00sazWvoTLOqg5MFwC68Um'}, 'href': 'https://api.spotify.com/v1/artists/00sazWvoTLOqg5MFwC68Um', 'id': '00sazWvoTLOqg5MFwC68Um', 'name': 'Yann Tiersen', 'type': 'artist', 'uri': 'spotify:artist:00sazWvoTLOqg5MFwC68Um'}], 'available_markets': ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT', 'AU', 'AZ', 'BA', 'BB', 'BD', 'BE', 'BF', 'BG', 'BH', 'BI', 'BJ', 'BN', 'BO', 'BR', 'BS', 'BT', 'BW', 'BY', 'BZ', 'CA', 'CD', 'CG', 'CH', 'CI', 'CL', 'CM', 'CO', 'CR', 'CV', 'CW', 'CY', 'CZ', 'DE', 'DJ', 'DK', 'DM', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FJ', 'FM', 'FR', 'GA', 'GB', 'GD', 'GE', 'GH', 'GM', 'GN', 'GQ', 'GR', 'GT', 'GW', 'GY', 'HK', 'HN', 'HR', 'HT', 'HU', 'ID', 'IE', 'IL', 'IN', 'IQ', 'IS', 'IT', 'JM', 'JO', 'JP', 'KE', 'KG', 'KH', 'KI', 'KM', 'KN', 'KR', 'KW', 'KZ', 'LA', 'LB', 'LC', 'LI', 'LK', 'LR', 'LS', 'LT', 'LU', 'LV', 'LY', 'MA', 'MC', 'MD', 'ME', 'MG', 'MH', 'MK', 'ML', 'MN', 'MO', 'MR', 'MT', 'MU', 'MV', 'MW', 'MX', 'MY', 'MZ', 'NA', 'NE', 'NG', 'NI', 'NL', 'NO', 'NP', 'NR', 'NZ', 'OM', 'PA', 'PE', 'PG', 'PH', 'PK', 'PL', 'PS', 'PT', 'PW', 'PY', 'QA', 'RO', 'RS', 'RU', 'RW', 'SA', 'SB', 'SC', 'SE', 'SG', 'SI', 'SK', 'SL', 'SM', 'SN', 'SR', 'ST', 'SV', 'SZ', 'TD', 'TG', 'TH', 'TJ', 'TL', 'TN', 'TO', 'TR', 'TT', 'TV', 'TW', 'TZ', 'UA', 'UG', 'US', 'UY', 'UZ', 'VC', 'VE', 'VN', 'VU', 'WS', 'XK', 'ZA', 'ZM', 'ZW'], 'disc_number': 1, 'duration_ms': 140733, 'explicit': False, 'external_ids': {'isrc': 'FR91U0100002'}, 'external_urls': {'spotify': 'https://open.spotify.com/track/14rZjW3RioG7WesZhYESso'}, 'href': 'https://api.spotify.com/v1/tracks/14rZjW3RioG7WesZhYESso', 'id': '14rZjW3RioG7WesZhYESso', 'is_local': False, 'name': "Comptine d'un autre été, l'après-midi", 'popul ...
# The keys of the dictionary are:  ['album', 'artists', 'available_markets', 'disc_number', 'duration_ms', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'name', 'popularity', 'preview_url', 'track_number', 'type', 'uri']

# %% [markdown]
# ## Checking albums

# %%
print(results["tracks"]["items"][0]["album"]) # we have more info about the album
print(list(results["tracks"]["items"][0]["album"].keys())) # Will check artists, id, name, release date, total tracks 
print(results["tracks"]["items"][0]["album"]["artists"]) # List with artists and information
print("The album ID is: ",results["tracks"]["items"][0]["album"]["id"]) # Album ID 
print(results["tracks"]["items"][0]["album"]["name"]) # Album name (if its a single u'll get the name of the song)
print(results["tracks"]["items"][0]["album"]["release_date"]) #date in YYYY-MM-DD format
print("Songs in the album: ",results["tracks"]["items"][0]["album"]["total_tracks"]) #songs in the album
# Out:
# {'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00sazWvoTLOqg5MFwC68Um'}, 'href': 'https://api.spotify.com/v1/artists/00sazWvoTLOqg5MFwC68Um', 'id': '00sazWvoTLOqg5MFwC68Um', 'name': 'Yann Tiersen', 'type': 'artist', 'uri': 'spotify:artist:00sazWvoTLOqg5MFwC68Um'}], 'available_markets': ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT', 'AU', 'AZ', 'BA', 'BB', 'BD', 'BE', 'BF', 'BG', 'BH', 'BI', 'BJ', 'BN', 'BO', 'BR', 'BS', 'BT', 'BW', 'BY', 'BZ', 'CA', 'CD', 'CG', 'CH', 'CI', 'CL', 'CM', 'CO', 'CR', 'CV', 'CW', 'CY', 'CZ', 'DE', 'DJ', 'DK', 'DM', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FJ', 'FM', 'FR', 'GA', 'GB', 'GD', 'GE', 'GH', 'GM', 'GN', 'GQ', 'GR', 'GT', 'GW', 'GY', 'HK', 'HN', 'HR', 'HT', 'HU', 'ID', 'IE', 'IL', 'IN', 'IQ', 'IS', 'IT', 'JM', 'JO', 'JP', 'KE', 'KG', 'KH', 'KI', 'KM', 'KN', 'KR', 'KW', 'KZ', 'LA', 'LB', 'LC', 'LI', 'LK', 'LR', 'LS', 'LT', 'LU', 'LV', 'LY', 'MA', 'MC', 'MD', 'ME', 'MG', 'MH', 'MK', 'ML', 'MN', 'MO', 'MR', 'MT', 'MU', 'MV', 'MW', 'MX', 'MY', 'MZ', 'NA', 'NE', 'NG', 'NI', 'NL', 'NO', 'NP', 'NR', 'NZ', 'OM', 'PA', 'PE', 'PG', 'PH', 'PK', 'PL', 'PS', 'PT', 'PW', 'PY', 'QA', 'RO', 'RS', 'RU', 'RW', 'SA', 'SB', 'SC', 'SE', 'SG', 'SI', 'SK', 'SL', 'SM', 'SN', 'SR', 'ST', 'SV', 'SZ', 'TD', 'TG', 'TH', 'TJ', 'TL', 'TN', 'TO', 'TR', 'TT', 'TV', 'TW', 'TZ', 'UA', 'UG', 'US', 'UY', 'UZ', 'VC', 'VE', 'VN', 'VU', 'WS', 'XK', 'ZA', 'ZM', 'ZW'], 'external_urls': {'spotify': 'https://open.spotify.com/album/6PRPYATK5VvjZ2p911y6U0'}, 'href': 'https://api.spotify.com/v1/albums/6PRPYATK5VvjZ2p911y6U0', 'id': '6PRPYATK5VvjZ2p911y6U0', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b2731b7844a8c73c4d48f0bca1de', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e021b7844a8c73c4d48f0bca1de', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d000048511b7844a8c73c4d48f0bca1de', 'width': 64}], 'name': "Le Fabuleux destin d'Amélie Poulain (Bande originale du film)", 'release_date': '2001-04-23', 'release_date_precision': 'day', 'total_tracks': 15, 'type': 'album', 'uri': 'spotify:album:6PRPYATK5VvjZ2p911y6U0'}
# ['album_type', 'artists', 'available_markets', 'external_urls', 'href', 'id', 'images', 'name', 'release_date', 'release_date_precision', 'total_tracks', 'type', 'uri']
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00sazWvoTLOqg5MFwC68Um'}, 'href': 'https://api.spotify.com/v1/artists/00sazWvoTLOqg5MFwC68Um', 'id': '00sazWvoTLOqg5MFwC68Um', 'name': 'Yann Tiersen', 'type': 'artist', 'uri': 'spotify:artist:00sazWvoTLOqg5MFwC68Um'}]
# The album ID is:  6PRPYATK5VvjZ2p911y6U0
# Le Fabuleux destin d'Amélie Poulain (Bande originale du film)
# 2001-04-23
# Songs in the album:  15

# %% [markdown]
# ## Other info

# %%
results["tracks"]["items"][0]["artists"] # Track artists
results["tracks"]["items"][0]["id"] # Track ID
results["tracks"]["items"][0]["name"] # Track name
results["tracks"]["items"][0]["popularity"] # Popularity index
results["tracks"]["items"][0]["uri"] # Basically ID
# Out:
# 'spotify:track:14rZjW3RioG7WesZhYESso'

# %% [markdown]
# # Exploring songs

# %% [markdown]
# ## Searching a playlist

# %%
playlist = sp.user_playlist_tracks("spotify", "4rnleEAOdmFAbRcNCgZMpY")

# %%
type(playlist)
# Out:
# dict

# %%
print(list(playlist.keys())) # Let's look at items and total:
print("Total number of songs in the playlist: ",playlist["total"]) # 4Ksongs!! Let's check items:
len(playlist["items"]) # It is limited to 100 tracks, we will have to fix it:
# Out:
# ['href', 'items', 'limit', 'next', 'offset', 'previous', 'total']
# Total number of songs in the playlist:  5295
# 100

# %% [markdown]
# ## Extracting the songs of a playlist

# %% [markdown]
# Pagination using "next"
# When you collect songs from a playlist using sp.playlist_tracks, you're limited by the limit parameter, which has a maximum (and default) value of 100. When the playlist has more than 100 songs, you have to collect them by navigating through the "pages" of the results.
#
# The parameter offset allows you to retrieve resuls starting at a certain position: if you start at position 101, you'd get the next "page" of results. An offset of 201 would give you the third page, and so on.
#
# The function sp.next() does the same, but in a simpler way: it can be used on the results from any request to directly retrieve the results for the next page.
#
# We can check whether there's a next page or not by accessing the key next on the results from any request.

# %%
def get_playlist_tracks(username, playlist_id):
    results = sp.user_playlist_tracks(username,playlist_id)
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

get_playlist_tracks("spotify", "4rnleEAOdmFAbRcNCgZMpY")
# Out:
# HTTP Error for GET to https://api.spotify.com/v1/playlists/4rnleEAOdmFAbRcNCgZMpY/tracks?offset=4700&limit=100&additional_types=track with Params: {} returned 404 due to None
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/spotipy/client.py in _internal_call(self, method, url, payload, params)
#     244
# --> 245             response.raise_for_status()
#     246             results = response.json()
#
# /usr/local/lib/python3.7/dist-packages/requests/models.py in raise_for_status(self)
#     959         if http_error_msg:
# --> 960             raise HTTPError(http_error_msg, response=self)
#     961
#
# HTTPError: 404 Client Error: Not Found for url: https://api.spotify.com/v1/playlists/4rnleEAOdmFAbRcNCgZMpY/tracks?offset=4700&limit=100&additional_types=track
#
# During handling of the above exception, another exception occurred:
#
# SpotifyException                          Traceback (most recent call last)
# <ipython-input-29-dcd17e666c27> in <module>()
#       7     return tracks
#       8
# ----> 9 get_playlist_tracks("spotify", "4rnleEAOdmFAbRcNCgZMpY")
#
# <ipython-input-29-dcd17e666c27> in get_playlist_tracks(username, playlist_id)
#       3     tracks = results['items']
#       4     while results['next']:
# ----> 5         results = sp.next(results)
#       6         tracks.extend(results['items'])
#       7     return tracks
#
# /usr/local/lib/python3.7/dist-packages/spotipy/client.py in next(self, result)
#     319         """
#     320         if result["next"]:
# --> 321             return self._get(result["next"])
#     322         else:
#     323             return None
#
# /usr/local/lib/python3.7/dist-packages/spotipy/client.py in _get(self, url, args, payload, **kwargs)
#     295             kwargs.update(args)
#     296
# --> 297         return self._internal_call("GET", url, payload, kwargs)
#     298
#     299     def _post(self, url, args=None, payload=None, **kwargs):
#
# /usr/local/lib/python3.7/dist-packages/spotipy/client.py in _internal_call(self, method, url, payload, params)
#     270                 "%s:\n %s" % (response.url, msg),
#     271                 reason=reason,
# --> 272                 headers=response.headers,
#     273             )
#     274         except requests.exceptions.RetryError as retry_error:
#
# SpotifyException: http status: 404, code:-1 - https://api.spotify.com/v1/playlists/4rnleEAOdmFAbRcNCgZMpY/tracks?offset=4700&limit=100&additional_types=track:
#  None, reason: None

# %% [markdown]
# ## Getting the artists of the playlist

# %%
def get_artists_from_track(track):
    return [artist["name"] for artist in track["artists"]]

# %%
def get_artists_from_playlist(playlist_id):
    tracks_from_playlist = get_playlist_tracks("spotify", playlist_id)
    return list(set(artist for subset in [get_artists_from_track(track["track"]) for track in tracks_from_playlist] for artist in subset))

# %%
get_artists_from_playlist("4rnleEAOdmFAbRcNCgZMpY")
# Out:
# HTTP Error for GET to https://api.spotify.com/v1/playlists/4rnleEAOdmFAbRcNCgZMpY/tracks?offset=400&limit=100&additional_types=track with Params: {} returned 404 due to None
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/spotipy/client.py in _internal_call(self, method, url, payload, params)
#     244
# --> 245             response.raise_for_status()
#     246             results = response.json()
#
# /usr/local/lib/python3.7/dist-packages/requests/models.py in raise_for_status(self)
#     959         if http_error_msg:
# --> 960             raise HTTPError(http_error_msg, response=self)
#     961
#
# HTTPError: 404 Client Error: Not Found for url: https://api.spotify.com/v1/playlists/4rnleEAOdmFAbRcNCgZMpY/tracks?offset=400&limit=100&additional_types=track
#
# During handling of the above exception, another exception occurred:
#
# SpotifyException                          Traceback (most recent call last)
# <ipython-input-32-31f543d2c3ad> in <module>()
# ----> 1 get_artists_from_playlist("4rnleEAOdmFAbRcNCgZMpY")
#
# <ipython-input-31-c16799c0df1a> in get_artists_from_playlist(playlist_id)
#       1 def get_artists_from_playlist(playlist_id):
# ----> 2     tracks_from_playlist = get_playlist_tracks("spotify", playlist_id)
#       3     return list(set(artist for subset in [get_artists_from_track(track["track"]) for track in tracks_from_playlist] for artist in subset))
#
# <ipython-input-29-dcd17e666c27> in get_playlist_tracks(username, playlist_id)
#       3     tracks = results['items']
#       4     while results['next']:
# ----> 5         results = sp.next(results)
#       6         tracks.extend(results['items'])
#       7     return tracks
#
# /usr/local/lib/python3.7/dist-packages/spotipy/client.py in next(self, result)
#     319         """
#     320         if result["next"]:
# --> 321             return self._get(result["next"])
#     322         else:
#     323             return None
#
# /usr/local/lib/python3.7/dist-packages/spotipy/client.py in _get(self, url, args, payload, **kwargs)
#     295             kwargs.update(args)
#     296
# --> 297         return self._internal_call("GET", url, payload, kwargs)
#     298
#     299     def _post(self, url, args=None, payload=None, **kwargs):
#
# /usr/local/lib/python3.7/dist-packages/spotipy/client.py in _internal_call(self, method, url, payload, params)
#     270                 "%s:\n %s" % (response.url, msg),
#     271                 reason=reason,
# --> 272                 headers=response.headers,
#     273             )
#     274         except requests.exceptions.RetryError as retry_error:
#
# SpotifyException: http status: 404, code:-1 - https://api.spotify.com/v1/playlists/4rnleEAOdmFAbRcNCgZMpY/tracks?offset=400&limit=100&additional_types=track:
#  None, reason: None

# %% [markdown]
# ## Artists ID

# %%
def get_artists_from_track(track):
    return[artist["name"] for artist in track["artists"]]

#--------------------------------------------------------------------

def get_artists_ids_from_track(track):
    return [artist["id"] for artist in track["artists"]]

# %%
def get_artists_ids_from_playlist(playlist_id):
    tracks_from_playlist = get_playlist_tracks("spotify", playlist_id)
    return list(set(artist for subset in [get_artists_ids_from_track(track["track"]) for track in tracks_from_playlist] for artist in subset))

# %%
artists = get_artists_from_playlist("4rnleEAOdmFAbRcNCgZMpY") # Apply the function
artists_ids = get_artists_ids_from_playlist("4rnleEAOdmFAbRcNCgZMpY")
len(artists)
len(artists_ids) # We might have more ids due to artists having the same name
# Out:
# HTTP Error for GET to https://api.spotify.com/v1/playlists/4rnleEAOdmFAbRcNCgZMpY/tracks?offset=2800&limit=100&additional_types=track with Params: {} returned 404 due to None
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/spotipy/client.py in _internal_call(self, method, url, payload, params)
#     244
# --> 245             response.raise_for_status()
#     246             results = response.json()
#
# /usr/local/lib/python3.7/dist-packages/requests/models.py in raise_for_status(self)
#     959         if http_error_msg:
# --> 960             raise HTTPError(http_error_msg, response=self)
#     961
#
# HTTPError: 404 Client Error: Not Found for url: https://api.spotify.com/v1/playlists/4rnleEAOdmFAbRcNCgZMpY/tracks?offset=2800&limit=100&additional_types=track
#
# During handling of the above exception, another exception occurred:
#
# SpotifyException                          Traceback (most recent call last)
# <ipython-input-35-53372f87a068> in <module>()
# ----> 1 artists = get_artists_from_playlist("4rnleEAOdmFAbRcNCgZMpY") # Apply the function
#       2 artists_ids = get_artists_ids_from_playlist("4rnleEAOdmFAbRcNCgZMpY")
#       3 len(artists)
#       4 len(artists_ids) # We might have more ids due to artists having the same name
#
# <ipython-input-31-c16799c0df1a> in get_artists_from_playlist(playlist_id)
#       1 def get_artists_from_playlist(playlist_id):
# ----> 2     tracks_from_playlist = get_playlist_tracks("spotify", playlist_id)
#       3     return list(set(artist for subset in [get_artists_from_track(track["track"]) for track in tracks_from_playlist] for artist in subset))
#
# <ipython-input-29-dcd17e666c27> in get_playlist_tracks(username, playlist_id)
#       3     tracks = results['items']
#       4     while results['next']:
# ----> 5         results = sp.next(results)
#       6         tracks.extend(results['items'])
#       7     return tracks
#
# /usr/local/lib/python3.7/dist-packages/spotipy/client.py in next(self, result)
#     319         """
#     320         if result["next"]:
# --> 321             return self._get(result["next"])
#     322         else:
#     323             return None
#
# /usr/local/lib/python3.7/dist-packages/spotipy/client.py in _get(self, url, args, payload, **kwargs)
#     295             kwargs.update(args)
#     296
# --> 297         return self._internal_call("GET", url, payload, kwargs)
#     298
#     299     def _post(self, url, args=None, payload=None, **kwargs):
#
# /usr/local/lib/python3.7/dist-packages/spotipy/client.py in _internal_call(self, method, url, payload, params)
#     270                 "%s:\n %s" % (response.url, msg),
#     271                 reason=reason,
# --> 272                 headers=response.headers,
#     273             )
#     274         except requests.exceptions.RetryError as retry_error:
#
# SpotifyException: http status: 404, code:-1 - https://api.spotify.com/v1/playlists/4rnleEAOdmFAbRcNCgZMpY/tracks?offset=2800&limit=100&additional_types=track:
#  None, reason: None

# %% [markdown]
# # Getting the info

# %% [markdown]
# In this section we will work with albums to extract information. We will start by extracting all the albums of an artist.

# %%
def get_albums_from_artist(artist_id):
    results = sp.artist_albums(artist_id, limit = 50)
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

# Same for albums ids
def get_album_ids_from_artist(artist_id):
    results = sp.artist_albums(artist_id, limit = 50)
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return [track["id"] for track in tracks]

# %% [markdown]
# Example: Coldplay

# %%
coldplay_id = "4gzpq5DPGxSnKTe4SA8HAU"
coldplay_albums = get_albums_from_artist(coldplay_id)
coldplay_album_ids = get_album_ids_from_artist(coldplay_id)

# Check artists that played with coldplay
set([artist["name"] for track in coldplay_albums for artist in track["artists"]])
# Out:
# {'Alexandre Desplat',
#  'Alyx Ander',
#  'BTS',
#  'Banda Sinfónica da Polícia de Seguranca Pública',
#  'Banda de Música da Força Aérea',
#  'Coldplay',
#  'David Guetta',
#  'Galantis',
#  'Greta Bradman',
#  'Jon Hopkins',
#  'José Manuel Ferreira Brito',
#  'Rhythms Del Mundo',
#  'Rihanna',
#  'Robin Schulz',
#  'SUGA',
#  'Seeb',
#  'Selena Gomez',
#  'Swedish House Mafia',
#  'The Chainsmokers',
#  'The String Family',
#  'Tiësto',
#  'Various Artists',
#  'ZHU'}

# %% [markdown]
# ## Getting the songs of a given album

# %%
def get_track_ids_from_albums(album_ids):
    return list(set([i["id"] for j in album_ids for i in sp.album(j)["tracks"]["items"]]))

# %%
coldplay_songs = get_track_ids_from_albums(coldplay_album_ids)

len(coldplay_songs)
# Out:
# 55174
